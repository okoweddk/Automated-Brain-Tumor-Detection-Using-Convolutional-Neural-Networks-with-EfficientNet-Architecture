# %% [markdown]
# <a href="https://colab.research.google.com/github/okoweddk/Automated-Brain-Tumor-Detection-Using-Convolutional-Neural-Networks-with-EfficientNet-Architecture/blob/main/Neurofybraintumourdetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CHIKAMADU SOPHIA OKORO
#
# OKO22608981
#
# Data Link: https://www.kaggle.com/datasets/shreyag1103/brain-mri-scans-for-brain-tumor-classification

# %%
# !pip install scikit-image==0.19.3 # Replace 0.19.3 with the desired version
# Out:
# Collecting scikit-image==0.19.3
#   Downloading scikit_image-0.19.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.19.3) (1.26.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.19.3) (1.13.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.19.3) (3.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.19.3) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.19.3) (2.34.2)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.19.3) (2024.8.10)
# Collecting PyWavelets>=1.1.1 (from scikit-image==0.19.3)
#   Downloading pywavelets-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.19.3) (24.1)
# Downloading scikit_image-0.19.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 19.7 MB/s eta 0:00:00
# Downloading pywavelets-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 25.4 MB/s eta 0:00:00
# Installing collected packages: PyWavelets, scikit-image
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.23.2
#     Uninstalling scikit-image-0.23.2:
#       Successfully uninstalled scikit-image-0.23.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.4.14 requires scikit-image>=0.21.0, but you have scikit-image 0.19.3 which is incompatible.
# Successfully installed PyWavelets-1.7.0 scikit-image-0.19.3

# %% [markdown]
# Libraries and Functions
#
# os:Provides a way of using operating system-dependent functionality such as reading or writing to the file system.
#
# cv2 (OpenCV):A powerful library for computer vision tasks. It's used for image processing and manipulation.
#
# Common functions include reading, writing, displaying images, and performing image transformations.
#
# numpy (np):A fundamental package for scientific computing in Python.
# Provides support for arrays, matrices, and many mathematical functions.
#
# pandas (pd):A library for data manipulation and analysis.
# Provides data structures like DataFrame, which is useful for handling structured data.
#
# skimage.feature (graycomatrix, graycoprops):Part of the scikit-image library, which is used for image processing.
#
# graycomatrix: Computes the gray-level co-occurrence matrix (GLCM), which is a statistical method of examining texture that considers the spatial relationship of pixels.
#
# graycoprops: Extracts texture properties such as contrast, dissimilarity, homogeneity, energy, and correlation from the GLCM.
#
# matplotlib.pyplot (plt):A plotting library used for creating static, animated, and interactive visualizations in Python.
#
# sklearn.model_selection (train_test_split):A module from scikit-learn used for splitting data into training and testing sets.Helps in evaluating the performance of a machine learning model by training it on one subset and testing it on another.
#
# sklearn.svm (SVC):Support Vector Classification, a type of Support Vector Machine (SVM) for classification tasks.
#
# SVM is a supervised machine learning algorithm used for classification or regression challenges.
#
# sklearn.metrics (classification_report, accuracy_score):Provides functions to evaluate the performance of machine learning models.
# classification_report: Generates a text report showing the main classification metrics.
#
# accuracy_score: Calculates the accuracy of the classification model. could you do this in a more descriptive manner

# %%
import os
import cv2
import numpy as np
import pandas as pd
from skimage.feature import graycomatrix, graycoprops # Correct function names
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score

# %% [markdown]
# Desciption of Dataset
#
#
#
# The section code is a Python script to count the number of images in each subfolder within a specified directory, and then display the total count of images across all subfolders

# %%
from google.colab import drive
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# The dataset, which consists of 685 images distributed among four classes, there is a noticeable class imbalance with the “No Tumor” category having the most images and “Meningioma” the fewest. This imbalance can significantly impact model performance, as the model may become biased towards the majority class (e.g., “No Tumor”), potentially leading to poorer performance on minority classes (e.g., “Meningioma”). Standard accuracy metrics might be misleading, as a model could achieve high accuracy by predominantly predicting the majority class. Therefore, it's crucial to use metrics like precision, recall, and F1-score to better assess performance across all classes. Additionally, class imbalance can affect training dynamics, making it necessary to consider techniques such as class weighting or resampling strategies to ensure the model learns effectively and generalizes well across all categories.

# %%
# Specify directories
data_dir =  '/content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/data'
image_dir = '/content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/data/Train'
test_dir = '/content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/data/Test'
# Step 1: Get the list of subfolders
subfolders = [f for f in os.listdir(image_dir) if os.path.isdir(os.path.join(image_dir, f))]

# Step 2: Initialize total image count
total_image_count = 0

# Step 3: Iterate over subfolders and count images
for subdir in subfolders:
    subdir_path = os.path.join(image_dir, subdir)
    if os.path.isdir(subdir_path):
        image_count = len([f for f in os.listdir(subdir_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif'))])
        print(f"Number of images in {subdir}: {image_count}")
        total_image_count += image_count

# Step 4: Display the total number of images
print(f"Total number of images: {total_image_count}")
# Out:
# Number of images in meningioma: 153
# Number of images in notumor: 203
# Number of images in glioma: 159
# Number of images in pituitary: 170
# Total number of images: 685

# %% [markdown]
# The session calculates the mean and standard deviation of pixel values for all images within each subfolder of a specified directory. It then prints these statistics for each subfolder.
#
#
# The mean pixel value of an image can provide an indication of the overall brightness or intensity. For example, a higher mean value suggests a brighter image, while a lower mean value indicates a darker image.
#
#
# The standard deviation of pixel values indicates the contrast or variability within the image. A higher standard deviation suggests more variability in pixel intensities, which typically means more contrast.

# %%
# Step 1: Get the list of subfolders
subfolders = [f for f in os.listdir(image_dir) if os.path.isdir(os.path.join(image_dir, f))]

# Step 2: Function to calculate mean and standard deviation for an image
def calculate_mean_std(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Load image in grayscale
    return np.mean(img), np.std(img)

# Step 3: Initialize dictionary to store mean and std for each folder
folder_stats = {}

# Step 4: Iterate over subfolders and calculate mean and std for each image
for subdir in subfolders:
    subdir_path = os.path.join(image_dir, subdir)
    if os.path.isdir(subdir_path):
        means = []
        stds = []
        for filename in os.listdir(subdir_path):
            if filename.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif')):
                image_path = os.path.join(subdir_path, filename)
                mean, std = calculate_mean_std(image_path)
                means.append(mean)
                stds.append(std)
        folder_stats[subdir] = {
            "mean": np.mean(means),
            "std": np.std(stds)
        }

# Step 5: Display the mean and standard deviation for each folder
for subdir, stats in folder_stats.items():
    print(f"Folder: {subdir}")
    print(f"  Mean of pixel values: {stats['mean']}")
    print(f"  Standard deviation of pixel values: {stats['std']}\n")
# Out:
# Folder: meningioma
#   Mean of pixel values: 43.535001468035134
#   Standard deviation of pixel values: 7.809089891715404
#
# Folder: notumor
#   Mean of pixel values: 60.11954471982759
#   Standard deviation of pixel values: 13.584535594418949
#
# Folder: glioma
#   Mean of pixel values: 37.91022496253439
#   Standard deviation of pixel values: 5.337624216363283
#
# Folder: pituitary
#   Mean of pixel values: 48.66313332950368
#   Standard deviation of pixel values: 5.018407412615199

# %%
# Extract folder names, means, and standard deviations
folder_names = list(folder_stats.keys())
means = [folder_stats[subdir]['mean'] for subdir in folder_names]
stds = [folder_stats[subdir]['std'] for subdir in folder_names]
# Create subplots
fig, ax = plt.subplots(1, 2, figsize=(14, 7))

# Plot means
ax[0].bar(folder_names, means, color='blue')
ax[0].set_title('Mean of Pixel Values per Folder')
ax[0].set_xlabel('Folder')
ax[0].set_ylabel('Mean Pixel Value')
ax[0].tick_params(axis='x', rotation=45)

# Plot standard deviations
ax[1].bar(folder_names, stds, color='pink')
ax[1].set_title('Standard Deviation of Pixel Values per Folder')
ax[1].set_xlabel('Folder')
ax[1].set_ylabel('Standard Deviation of Pixel Value')
ax[1].tick_params(axis='x', rotation=45)

# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %%
output_dir = '/content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT'
# Resizing images
def resize_image(image, new_width=None, new_height=None, inter=cv2.INTER_AREA):
    (h, w) = image.shape[:2]
    if new_width is None and new_height is None:
        return image

    if new_width is None:
        r = new_height / float(h)
        dim = (int(w * r), new_height)
    else:
        r = new_width / float(w)
        dim = (new_width, int(h * r))

    resized = cv2.resize(image, dim, interpolation=inter)
    return resized

def resize_images_in_folder(image_dir, output_dir, new_width=None, new_height=None):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    resized_images = []

    for root, _, files in os.walk(image_dir):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
                input_path = os.path.join(root, file)
                relative_path = os.path.relpath(root, image_dir)
                output_path = os.path.join(output_dir, relative_path)

                if not os.path.exists(output_path):
                    os.makedirs(output_path)

                image = cv2.imread(input_path)
                if image is None:
                    continue

                resized_image = resize_image(image, new_width, new_height)
                cv2.imwrite(os.path.join(output_path, file), resized_image)
                print(f"Resized image saved to: {os.path.join(output_path, file)}")

                # Collect the resized images and their paths for visualization
                resized_images.append((file, resized_image))

    return resized_images

def visualize_images(images, indices, figsize=(15, 10)):
    num_images = len(indices)
    fig, axes = plt.subplots(1, num_images, figsize=figsize)

    for i, idx in enumerate(indices):
        filename, image = images[idx]
        axes[i].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        axes[i].set_title(filename)
        axes[i].axis('off')

    plt.tight_layout()
    plt.show()

new_width = 300
new_height = 300

resized_images = resize_images_in_folder(image_dir, output_dir, new_width, new_height)

# Specify indices of the images you want to visualize (e.g., first 5 images)
num_images_to_display = 5
indices = list(range(min(num_images_to_display, len(resized_images))))

visualize_images(resized_images, indices)
# Out:
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-meTr_0000.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0239.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0241.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-meTr_0007.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-meTr_0001.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-meTr_0004.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-meTr_0005.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0242.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0245.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0240.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0243.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-meTr_0008.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0246.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-meTr_0006.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0248.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-meTr_0002.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-meTr_0009.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0247.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0249.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0250.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-meTr_0003.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0163.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0164.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0244.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0251.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0253.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0168.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0169.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0252.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0167.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0254.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0166.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0171.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0255.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0256.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0165.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0257.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0173.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0170.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0174.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0259.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0258.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0175.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0260.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0172.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0262.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0263.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0179.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0177.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0264.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0261.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0176.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0181.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0265.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0178.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0267.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0183.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0266.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0268.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0180.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0270.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0182.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0269.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0184.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0185.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0272.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0271.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0191.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0187.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0274.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0275.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0190.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0276.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0186.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0189.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0273.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0188.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0193.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0279.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0277.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0192.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0281.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0278.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0194.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0196.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0197.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0282.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0199.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0280.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0195.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0284.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0283.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0200.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0286.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0202.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0285.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0287.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0288.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0201.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0198.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0290.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0204.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0203.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0289.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0205.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0207.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0293.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0294.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0212.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0297.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0296.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0208.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0206.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0295.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0210.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0291.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0209.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0292.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0300.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0211.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0298.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0213.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0301.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0214.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0302.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0216.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0218.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0299.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0215.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0304.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0220.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0305.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0219.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0217.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0303.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0221.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0223.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0222.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0224.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0226.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0225.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0227.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0228.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0229.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0230.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0231.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0232.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0234.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0233.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0235.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0237.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0238.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0236.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-noTr_0000.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-noTr_0003.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-noTr_0001.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-noTr_0005.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-noTr_0002.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-noTr_0009.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-noTr_0006.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-noTr_0004.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-noTr_0008.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-noTr_0007.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0212.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0216.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0213.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0214.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0215.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0218.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0217.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0221.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0220.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0307.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0219.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0226.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0309.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0222.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0308.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0224.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0223.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0310.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0311.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0225.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0228.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0312.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0313.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0229.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0314.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0227.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0315.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0231.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0318.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0232.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0317.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0316.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0230.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0233.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0321.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0237.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0320.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0238.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0319.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0236.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0323.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0234.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0324.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0322.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0235.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0241.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0240.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0326.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0239.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0325.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0243.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0242.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0327.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0330.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0244.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0328.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0246.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0331.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0245.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0329.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0248.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0332.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0247.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0333.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0334.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0249.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0250.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0335.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0251.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0336.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0254.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0338.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0252.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0337.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0253.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0339.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0256.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0341.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0255.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0343.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0258.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0342.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0257.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0340.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0344.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0259.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0262.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0345.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0260.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0346.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0261.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0348.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0265.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0347.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0264.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0352.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0263.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0350.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0268.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0349.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0266.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0351.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0267.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0355.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0354.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0269.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0270.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0353.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0271.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0356.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0358.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0274.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0272.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0357.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0276.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0360.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0359.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0275.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0277.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0278.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0362.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0361.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0273.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0365.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0281.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0368.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0364.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0279.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0280.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0363.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0282.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0369.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0283.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0366.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0286.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0372.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0284.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0367.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0285.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0370.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0287.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0371.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0288.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0375.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0289.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0373.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0378.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0291.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0290.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0377.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0379.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0294.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0293.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0376.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0292.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0374.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0295.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0383.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0296.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0382.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0298.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0386.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0297.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0380.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0300.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0381.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0299.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0384.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0303.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0385.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0301.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0389.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0304.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0387.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0306.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0388.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0302.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0305.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0393.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0390.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0391.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0394.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0392.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0395.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0397.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0396.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0398.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0400.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0399.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0401.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0402.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0403.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0404.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0214.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0216.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0217.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0218.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0219.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0220.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0221.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0225.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0223.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0222.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0224.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-glTr_0000.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0229.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0226.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-glTr_0001.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-glTr_0002.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-glTr_0003.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0227.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-glTr_0005.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0232.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-glTr_0004.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0228.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-glTr_0007.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0230.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0233.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0231.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-glTr_0006.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-glTr_0008.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0234.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0150.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0235.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-glTr_0009.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0236.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0152.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0237.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0151.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0238.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0153.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0239.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0242.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0154.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0240.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0155.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0243.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0157.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0156.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0159.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0241.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0160.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0246.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0158.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0249.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0244.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0162.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0163.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0245.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0250.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0166.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0247.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0165.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0251.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0248.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0164.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0167.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0252.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0253.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0168.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0169.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0256.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0171.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0254.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0173.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0255.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0174.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0257.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0172.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0258.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0170.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0260.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0261.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0175.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0176.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0259.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0177.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0263.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0178.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0181.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0262.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0266.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0180.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0268.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0179.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0183.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0265.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0264.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0182.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0269.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0185.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0267.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0186.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0270.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0184.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0272.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0187.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0271.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0188.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0189.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0274.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0190.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0191.jpg
# ...
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-piTr_0009.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0227.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0140.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0141.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0224.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0144.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0229.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0225.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0145.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0143.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0226.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0146.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0233.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0147.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0234.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0142.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0230.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0231.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0149.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0151.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0150.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0236.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0232.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0148.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0235.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0242.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0157.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0243.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0152.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0244.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0154.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0238.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0153.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0155.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0240.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0239.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0158.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0241.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0156.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0237.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0159.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0249.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0162.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0245.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0161.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0248.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0160.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0251.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0250.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0166.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0167.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0247.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0165.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0246.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0164.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0258.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0171.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0252.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0163.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0257.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0169.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0170.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0256.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0254.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0172.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0253.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0261.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0168.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0255.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0176.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0177.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0262.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0175.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0263.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0178.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0259.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0173.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0260.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0174.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0266.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0182.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0269.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0264.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0183.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0181.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0265.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0179.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0267.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0180.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0270.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0187.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0272.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0268.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0188.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0274.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0271.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0275.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0186.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0185.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0277.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0184.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0273.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0191.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0276.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0278.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0194.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0282.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0285.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0189.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0280.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0190.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0279.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0193.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0284.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0192.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0286.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0197.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0283.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0195.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0281.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0196.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0295.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0198.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0287.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0200.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0290.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0199.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0294.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0204.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0291.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0292.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0203.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0205.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0288.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0206.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0289.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0293.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0207.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0202.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0298.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0201.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0299.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0209.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0297.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0215.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0296.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0208.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0211.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0210.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0212.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0213.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0214.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0216.jpg

# %% [markdown]
# Recalculating the mean and standard deviation after resizing ensures accurate statistics for resized images, which is crucial for consistent and effective preprocessing in image analysis and machine learning tasks. This process helps maintain uniformity across the dataset, enabling better model performance and more reliable analysis.

# %%
# Step 1: Get the list of subfolders
subfolders = [f for f in os.listdir(output_dir) if os.path.isdir(os.path.join(output_dir, f))]

# Step 2: Function to calculate mean and standard deviation for an image
def calculate_mean_std(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Load image in grayscale
    return np.mean(img), np.std(img)

# Step 3: Initialize dictionary to store mean and std for each folder
folder_stats = {}

# Step 4: Iterate over subfolders and calculate mean and std for each image
for subdir in subfolders:
    subdir_path = os.path.join(output_dir, subdir)
    if os.path.isdir(subdir_path):
        means = []
        stds = []
        for filename in os.listdir(subdir_path):
            if filename.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif')):
                image_path = os.path.join(subdir_path, filename)
                mean, std = calculate_mean_std(image_path)
                means.append(mean)
                stds.append(std)
        folder_stats[subdir] = {
            "mean": np.mean(means),
            "std": np.std(stds)
        }

# Step 5: Display the mean and standard deviation for each folder
for subdir, stats in folder_stats.items():
    print(f"Folder: {subdir}")
    print(f"  Mean of pixel values: {stats['mean']}")
    print(f"  Standard deviation of pixel values: {stats['std']}\n")
# Out:
# Folder: meningioma
#   Mean of pixel values: 52.223517248441375
#   Standard deviation of pixel values: 12.392487026844563
#
# Folder: notumor
#   Mean of pixel values: 58.74861723160402
#   Standard deviation of pixel values: 15.35109734085805
#
# Folder: glioma
#   Mean of pixel values: 33.807790439337836
#   Standard deviation of pixel values: 5.17336457043913
#
# Folder: pituitary
#   Mean of pixel values: 47.36545000354908
#   Standard deviation of pixel values: 5.572600762452981

# %% [markdown]
# Morphogical Operations
#
#
#
#
# This script is designed to enhance image quality by applying noise reduction techniques, specifically Gaussian blur and Median filtering, to each image in a given directory. Gaussian blur smooths the image to reduce noise and detail, while the Median filter further removes noise, particularly effective against salt-and-pepper noise. To optimize performance, the script employs parallel processing through Python's multiprocessing library, enabling it to handle multiple images concurrently and significantly speed up the overall processing time. The script systematically traverses the specified directory and its subdirectories, identifying all image files with common extensions (e.g., .jpg, .png, .tif) and applying the noise reduction techniques to each. The processed images are then saved to a specified output directory, maintaining the original directory structure. This approach is especially beneficial for handling large datasets where processing efficiency is crucial.

# %%
# Number of images per class
meningioma = 153
notumor = 203
glioma = 159
pituitary = 170
total_images = 685

# Proportions for each class
prop_meningioma = meningioma / total_images
prop_notumor = notumor / total_images
prop_glioma = glioma / total_images
prop_pituitary = pituitary / total_images

# Print proportions
print(f"Proportion of meningioma: {prop_meningioma:.2f}")
print(f"Proportion of notumor: {prop_notumor:.2f}")
print(f"Proportion of glioma: {prop_glioma:.2f}")
print(f"Proportion of pituitary: {prop_pituitary:.2f}")
# Out:
# Proportion of meningioma: 0.22
# Proportion of notumor: 0.30
# Proportion of glioma: 0.23
# Proportion of pituitary: 0.25

# %%
import matplotlib.pyplot as plt

# Data for the pie chart
class_names = ['Meningioma', 'Notumor', 'Glioma', 'Pituitary']
class_counts = [153, 203, 159, 170]

# Create a pie chart
plt.figure(figsize=(4, 4))
plt.pie(class_counts, labels=class_names, autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])
plt.title('Class Distribution in Dataset')
plt.show()

# %%
import os
from multiprocessing import Pool

# Define noise reduction parameters
gaussian_kernel_size = (5, 5)
median_ksize = 5

# Function to apply noise reduction techniques
def process_image(image_path):
    # Load the image
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    if image is None:
        return

    # Apply Gaussian blur
    blurred_image = cv2.GaussianBlur(image, gaussian_kernel_size, 0)

    # Apply Median filter
    median_filtered_image = cv2.medianBlur(blurred_image, median_ksize)

    # Create output path
    relative_path = os.path.relpath(image_path, image_dir)
    output_path = os.path.join(output_dir, relative_path)
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

    # Save the filtered image
    cv2.imwrite(output_path, median_filtered_image)

# Function to process all images in a directory
def process_directory(image_dir, output_dir):
    # Get a list of all image files
    image_files = [os.path.join(root, file)
                   for root, dirs, files in os.walk(image_dir)
                   for file in files
                   if file.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tif', '.tiff'))]

    # Use multiprocessing to process images in parallel
    with Pool() as pool:
        pool.map(process_image, image_files)


process_directory(image_dir, output_dir)

# %%
# Function to get image file paths grouped by folder name
def get_image_files_by_folder(directory):
    folder_images = {}

    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tif', '.tiff')):
                # Get the folder name
                folder_name = os.path.basename(root)
                if folder_name not in folder_images:
                    folder_images[folder_name] = []
                # Append the file path to the corresponding folder
                folder_images[folder_name].append(os.path.join(root, file))

    return folder_images

# Import the random module
import random

# Function to display a set of images from each folder
def display_images_by_folder(folder_images, num_images_per_folder=5):
    plt.figure(figsize=(15, 10))

    # Counter for subplot positions
    subplot_index = 1

    for folder_name, image_files in folder_images.items():
        # Randomly select a subset of images from the folder
        selected_files = random.sample(image_files, min(num_images_per_folder, len(image_files)))

        for file_path in selected_files:
            # Load the image
            image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
            if image is None:
                continue

            # Display the image
            plt.subplot(len(folder_images), num_images_per_folder, subplot_index)
            plt.imshow(image, cmap='gray')
            plt.title(folder_name)
            plt.axis('off')
            subplot_index += 1

    plt.tight_layout()
    plt.show()

# Get image files grouped by folder
folder_images = get_image_files_by_folder(output_dir)

# Display images from each folder
display_images_by_folder(folder_images, num_images_per_folder=2)

# %% [markdown]
# This script is designed for loading images from a structured folder, extracting Histogram of Oriented Gradients (HOG) features from these images, encoding the labels, splitting the data into training and testing sets, standardizing the features, and defining a parameter grid for hyperparameter tuning of a Support Vector Machine (SVM) model. Here’s a detailed breakdown of the script

# %%
import os
import numpy as np
from skimage.io import imread
from skimage.feature import hog
from skimage.transform import resize
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

def load_images_from_folder(folder_path):
    images = []
    labels = []
    for label in os.listdir(folder_path):
        subfolder = os.path.join(folder_path, label)
        if os.path.isdir(subfolder):
            for filename in os.listdir(subfolder):
                img_path = os.path.join(subfolder, filename)
                img = imread(img_path, as_gray=True) # Load as grayscale
                # Resize images to a consistent size
                img = resize(img, (128, 128)) # Example size, adjust as needed
                # Extract HOG features and flatten them
                features = hog(img, visualize=False)
                images.append(features)
                labels.append(label)
    return np.array(images), np.array(labels)

# Define your dataset path
dataset_path = '/content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT'

# Load images and labels
X, y = load_images_from_folder(dataset_path)

# Encode labels
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Define parameter grid
param_grid = {
    'kernel': ['linear','rbf', 'poly'],
    'C': [0.1, 1, 10, 100],  # Regularization parameter
    'gamma': ['scale', 'auto']  # For RBF and Polynomial kernels
}

# %% [markdown]
# This script efficiently prepares image data for classification using HOG feature extraction. It loads images from a folder structure, extracts features, encodes labels, and splits the data into training and testing sets. The features are standardized, and a parameter grid is defined for SVM hyperparameter tuning. This setup is essential for training a robust image classification model with optimal hyperparameters.

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, roc_curve, auc, roc_auc_score
from sklearn.preprocessing import LabelBinarizer

# %% [markdown]
# This script segment completes the machine learning pipeline by:
#
# Initializing and Tuning: An SVM classifier is initialized, and grid search is employed for hyperparameter tuning. This ensures that the optimal parameters for the model are found, enhancing its performance.
#
# Training and Predicting: The model is trained using the training data, and predictions are made on the test data. This step verifies how well the model generalizes to unseen data.
#
# Evaluating: The model's performance is evaluated using a confusion matrix and a classification report. These metrics provide detailed insights into the model's accuracy, precision, recall, and f1-score for each class, highlighting its performance in different areas.
#
# Visualization: The confusion matrix is plotted, offering a visual representation of the model's performance. This helps in quickly identifying where the model is performing well and where it might be making errors.
#
# This comprehensive approach ensures that the model is not only optimized for performance but also thoroughly evaluated to understand its strengths and weaknesses. By doing so, it provides a clear picture of the model's effectiveness and areas for potential improvement.

# %%
# Initialize the SVM classifier with probability=True
svc = SVC(probability=True)

# Initialize GridSearchCV
grid_search = GridSearchCV(svc, param_grid, cv=5, n_jobs=-1, scoring='accuracy')

# Fit the model
grid_search.fit(X_train, y_train)

# Get the best parameters and model
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

print(f"Best Parameters: {best_params}")

# Make predictions
y_pred = best_model.predict(X_test)

# Assuming 'label_encoder' is the LabelEncoder used earlier
label_names = label_encoder.classes_

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Print the classification report with zero_division set to 0
print("Classification Report with zero_division=0:")
print(classification_report(y_test, y_pred, target_names=label_names, zero_division=0))
# Out:
# Best Parameters: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Classification Report with zero_division=0:
#               precision    recall  f1-score   support
#
#       glioma       0.82      0.88      0.85        85
#   meningioma       0.79      0.67      0.72        90
#      notumor       0.97      0.96      0.96       128
#    pituitary       0.85      0.92      0.88        91
#
#     accuracy                           0.87       394
#    macro avg       0.86      0.86      0.85       394
# weighted avg       0.87      0.87      0.87       394

# %%
# Calculate and print additional metrics
from sklearn.preprocessing import LabelBinarizer # Import the LabelBinarizer class
from sklearn.metrics import roc_curve, auc # Import roc_curve and auc here

# Calculate and print additional metrics
def calculate_metrics(cm):
    FP = cm.sum(axis=0) - np.diag(cm)
    FN = cm.sum(axis=1) - np.diag(cm)
    TP = np.diag(cm)
    TN = cm.sum() - (FP + FN + TP)

    # Sensitivity, hit rate, recall, or true positive rate
    TPR = TP / (TP + FN)
    # Specificity or true negative rate
    TNR = TN / (TN + FP)
    # Precision or positive predictive value
    PPV = TP / (TP + FP)
    # Negative predictive value
    NPV = TN / (TN + FN)
    # Fall out or false positive rate
    FPR = FP / (FP + TN)
    # False negative rate
    FNR = FN / (TP + FN)
    # False discovery rate
    FDR = FP / (TP + FP)
    # F1 score
    F1 = 2 * (PPV * TPR) / (PPV + TPR)

    return TPR, TNR, F1

# Calculate the additional metrics
TPR, TNR, F1 = calculate_metrics(cm)

print("Additional Metrics:")
print(f"True Positive Rate (Recall): {TPR}")
print(f"True Negative Rate (Specificity): {TNR}")
print(f"F1 Score: {F1}")

# Plot ROC curve for each class
lb = LabelBinarizer()
y_test_binarized = lb.fit_transform(y_test)

if len(label_names) == 2:  # Binary classification
    y_score = best_model.decision_function(X_test)
    fpr, tpr, _ = roc_curve(y_test_binarized, y_score)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc='lower right')
    plt.show()
else:  # Multi-class classification
    y_score = best_model.predict_proba(X_test)
    plt.figure()
    for i in range(len(label_names)):
        fpr, tpr, _ = roc_curve(y_test_binarized[:, i], y_score[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, label=f'ROC curve of class {label_names[i]} (area = {roc_auc:.2f})')

    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic for Multi-class')
    plt.legend(loc='lower right')
    plt.show()
# Out:
# Additional Metrics:
# True Positive Rate (Recall): [0.88235294 0.66666667 0.9609375  0.92307692]
# True Negative Rate (Specificity): [0.94498382 0.94736842 0.98496241 0.95049505]
# F1 Score: [0.84745763 0.72289157 0.96470588 0.88421053]

# %%
 # Function to get image file paths grouped by folder name
def get_image_files_by_folder(directory):
    folder_images = {}

    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tif', '.tiff')):
                # Get the folder name
                folder_name = os.path.basename(root)
                if folder_name not in folder_images:
                    folder_images[folder_name] = []
                # Append the file path to the corresponding folder
                folder_images[folder_name].append(os.path.join(root, file))

    return folder_images

# %%
def load_images_from_folder(folder_path):
    images = []
    labels = []
    for label in os.listdir(folder_path):
        subfolder = os.path.join(folder_path, label)
        if os.path.isdir(subfolder):
            for filename in os.listdir(subfolder):
                img_path = os.path.join(subfolder, filename)
                img = imread(img_path, as_gray=True) # Load as grayscale
                # Resize images to a consistent size
                img = resize(img, (128, 128)) # Example size, adjust as needed
                # Extract HOG features and flatten them
                features = hog(img, visualize=False)
                images.append(features)
                labels.append(label)
    return np.array(images), np.array(labels)

# %%
# Load images and labels
X, y = load_images_from_folder(dataset_path)

# Encode labels
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns # Import seaborn for heatmap plotting

# Get the unique class labels from the original 'y' array
label_names = label_encoder.classes_

# Initialize the Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the Random Forest model
rf_classifier.fit(X_train, y_train)

# Make predictions
y_pred_rf = rf_classifier.predict(X_test)

# Evaluate the Random Forest model
print("Random Forest Classification Report:")
print(classification_report(y_test, y_pred_rf, target_names=label_names, zero_division=0))

cm_rf = confusion_matrix(y_test, y_pred_rf)
plt.figure(figsize=(10, 7))
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Random Forest Confusion Matrix')
plt.show()
# Out:
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#       glioma       0.80      0.82      0.81        85
#   meningioma       0.79      0.59      0.68        90
#      notumor       0.93      0.97      0.95       128
#    pituitary       0.83      0.98      0.90        91
#
#     accuracy                           0.85       394
#    macro avg       0.84      0.84      0.83       394
# weighted avg       0.85      0.85      0.85       394

# %%
# Calculate and print additional metrics
from sklearn.preprocessing import LabelBinarizer # Import the LabelBinarizer class
from sklearn.metrics import roc_curve, auc # Import roc_curve and auc here

# Calculate and print additional metrics
def calculate_metrics(cm):
    FP = cm.sum(axis=0) - np.diag(cm)
    FN = cm.sum(axis=1) - np.diag(cm)
    TP = np.diag(cm)
    TN = cm.sum() - (FP + FN + TP)

    # Sensitivity, hit rate, recall, or true positive rate
    TPR = TP / (TP + FN)
    # Specificity or true negative rate
    TNR = TN / (TN + FP)
    # Precision or positive predictive value
    PPV = TP / (TP + FP)
    # Negative predictive value
    NPV = TN / (TN + FN)
    # Fall out or false positive rate
    FPR = FP / (FP + TN)
    # False negative rate
    FNR = FN / (TP + FN)
    # False discovery rate
    FDR = FP / (TP + FP)
    # F1 score
    F1 = 2 * (PPV * TPR) / (PPV + TPR)

    return TPR, TNR, F1

# Calculate the additional metrics
TPR, TNR, F1 = calculate_metrics(cm)

print("Additional Metrics:")
print(f"True Positive Rate (Recall): {TPR}")
print(f"True Negative Rate (Specificity): {TNR}")
print(f"F1 Score: {F1}")

# Plot ROC curve for each class
lb = LabelBinarizer()
y_test_binarized = lb.fit_transform(y_test)

if len(label_names) == 2:  # Binary classification
    y_score = best_model.decision_function(X_test)
    fpr, tpr, _ = roc_curve(y_test_binarized, y_score)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc='lower right')
    plt.show()
else:  # Multi-class classification
    y_score = best_model.predict_proba(X_test)
    plt.figure()
    for i in range(len(label_names)):
        fpr, tpr, _ = roc_curve(y_test_binarized[:, i], y_score[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, label=f'ROC curve of class {label_names[i]} (area = {roc_auc:.2f})')

    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic for Multi-class')
    plt.legend(loc='lower right')
    plt.show()
# Out:
# Additional Metrics:
# True Positive Rate (Recall): [0.88235294 0.66666667 0.9609375  0.92307692]
# True Negative Rate (Specificity): [0.94498382 0.94736842 0.98496241 0.95049505]
# F1 Score: [0.84745763 0.72289157 0.96470588 0.88421053]

# %%
import os
import numpy as np
from skimage.feature import hog
from skimage.io import imread
from skimage.transform import resize
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Function to extract HOG features from an image
def extract_hog_features(image_path):
    """Extract HOG features from an image."""
    image = imread(image_path, as_gray=True)
    # Resize the image to a consistent size
    image = resize(image, (128, 64)) # Adjust the size as needed
    features, _ = hog(image, visualize=True, block_norm='L2-Hys')
    return features

# Function to extract features and labels from images in a folder
def extract_features_from_folder(folder_path):
    """Extract HOG features from all images in a folder and their labels."""
    X = []
    y = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff')):
                image_path = os.path.join(root, file)
                features = extract_hog_features(image_path)
                X.append(features)
                label = os.path.basename(root)  # Assuming the folder name is the label
                y.append(label)
    return np.array(X), np.array(y)

# Load and prepare the data
image_folder = '/content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT'
X, y = extract_features_from_folder(image_folder)

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Initialize and train the KNN classifier
knn_classifier = KNeighborsClassifier(n_neighbors=5)
knn_classifier.fit(X_train, y_train)

# Make predictions
y_pred_knn = knn_classifier.predict(X_test)
y_prob_knn = knn_classifier.predict_proba(X_test)

# Evaluate the KNN model
print("KNN Classification Report:")
print(classification_report(y_test, y_pred_knn, target_names=label_encoder.classes_, zero_division=0))

# Plot confusion matrix
cm_knn = confusion_matrix(y_test, y_pred_knn)
plt.figure(figsize=(10, 7))
sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('KNN Confusion Matrix')
plt.show()
# Out:
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#       glioma       0.70      0.84      0.76        62
#   meningioma       0.74      0.37      0.49        62
#      notumor       0.91      0.96      0.94        77
#    pituitary       0.75      0.94      0.83        62
#
#     accuracy                           0.79       263
#    macro avg       0.78      0.78      0.76       263
# weighted avg       0.79      0.79      0.77       263

# %%
# Calculate additional metrics
def calculate_metrics(cm):
    FP = cm.sum(axis=0) - np.diag(cm)
    FN = cm.sum(axis=1) - np.diag(cm)
    TP = np.diag(cm)
    TN = cm.sum() - (FP + FN + TP)

    TPR = TP / (TP + FN)
    TNR = TN / (TN + FP)
    PPV = TP / (TP + FP)
    NPV = TN / (TN + FN)
    FPR = FP / (FP + TN)
    FNR = FN / (TP + FN)
    FDR = FP / (TP + FP)
    F1 = 2 * (PPV * TPR) / (PPV + TPR)

    return TPR, TNR, F1

# Calculate the additional metrics
TPR, TNR, F1 = calculate_metrics(cm_knn)

print("Additional Metrics:")
print(f"True Positive Rate (Recall): {TPR}")
print(f"True Negative Rate (Specificity): {TNR}")
print(f"F1 Score: {F1}")

# Plot ROC curve for each class
lb = LabelBinarizer()
y_test_binarized = lb.fit_transform(y_test)

if len(label_encoder.classes_) == 2:  # Binary classification
    fpr, tpr, _ = roc_curve(y_test_binarized, y_prob_knn[:, 1])
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc='lower right')
    plt.show()
else:  # Multi-class classification
    plt.figure()
    for i in range(len(label_encoder.classes_)):
        fpr, tpr, _ = roc_curve(y_test_binarized[:, i], y_prob_knn[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, label=f'ROC curve of class {label_encoder.classes_[i]} (area = {roc_auc:.2f})')

    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic for Multi-class')
    plt.legend(loc='lower right')
    plt.show()
# Out:
# Additional Metrics:
# True Positive Rate (Recall): [0.83870968 0.37096774 0.96103896 0.93548387]
# True Negative Rate (Specificity): [0.89054726 0.960199   0.96236559 0.90547264]
# F1 Score: [0.76470588 0.49462366 0.93670886 0.83453237]

# %%
import joblib

# Save the trained KNN model
knn_filename = 'knn_model.pkl'
joblib.dump(knn_classifier, knn_filename)
print(f"Model saved as {knn_filename}")

# Save the trained SVM model
svm_filename = 'svm_model.pkl'
joblib.dump(best_model, svm_filename)
print(f"Model saved as {svm_filename}")

# Save the trained Random Forest model
rf_filename = 'random_forest_model.pkl'
joblib.dump(rf_classifier, rf_filename)
print(f"Model saved as {rf_filename}")
# Out:
# Model saved as knn_model.pkl
# Model saved as svm_model.pkl
# Model saved as random_forest_model.pkl

# %%
input_dir = '/content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/INPUT'
# Resizing images
def resize_image(image, new_width=None, new_height=None, inter=cv2.INTER_AREA):
    (h, w) = image.shape[:2]
    if new_width is None and new_height is None:
        return image

    if new_width is None:
        r = new_height / float(h)
        dim = (int(w * r), new_height)
    else:
        r = new_width / float(w)
        dim = (new_width, int(h * r))

    resized = cv2.resize(image, dim, interpolation=inter)
    return resized

def resize_images_in_folder(test_dir, input_dir, new_width=None, new_height=None):
    if not os.path.exists(input_dir):
        os.makedirs(input_dir)

    resized_images = []

    for root, _, files in os.walk(test_dir):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
                input_path = os.path.join(root, file)
                relative_path = os.path.relpath(root, test_dir)
                output_path = os.path.join(output_dir, relative_path)

                if not os.path.exists(output_path):
                    os.makedirs(output_path)

                image = cv2.imread(input_path)
                if image is None:
                    continue

                resized_image = resize_image(image, new_width, new_height)
                cv2.imwrite(os.path.join(output_path, file), resized_image)
                print(f"Resized image saved to: {os.path.join(output_path, file)}")

                # Collect the resized images and their paths for visualization
                resized_images.append((file, resized_image))

    return resized_images

def visualize_images(images, indices, figsize=(15, 10)):
    num_images = len(indices)
    fig, axes = plt.subplots(1, num_images, figsize=figsize)

    for i, idx in enumerate(indices):
        filename, image = images[idx]
        axes[i].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        axes[i].set_title(filename)
        axes[i].axis('off')

    plt.tight_layout()
    plt.show()

new_width = 300
new_height = 300

resized_images = resize_images_in_folder(test_dir, input_dir, new_width, new_height)

# Specify indices of the images you want to visualize (e.g., first 5 images)
num_images_to_display = 5
indices = list(range(min(num_images_to_display, len(resized_images))))

visualize_images(resized_images, indices)
# Out:
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0010.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0011.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0012.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0013.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0014.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0015.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0016.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0017.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0018.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0019.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0020.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0021.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0022.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0023.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0024.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0025.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0026.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0027.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0028.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0029.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0030.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0031.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0032.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0033.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0034.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0035.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0036.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0037.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0038.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0039.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0040.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0041.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0042.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0043.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0044.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0045.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0046.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0047.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0048.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0049.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0050.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0051.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0052.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0053.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0054.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0055.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0057.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0056.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0058.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0059.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0060.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0061.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0062.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0063.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0065.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0064.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0066.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0067.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0068.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0069.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0070.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0071.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0072.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0073.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0074.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0075.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0077.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0076.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0078.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0079.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0080.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0081.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0082.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0083.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0084.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0085.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0086.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0087.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0088.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0089.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0090.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0091.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0092.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0093.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0094.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0095.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0096.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0097.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0098.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0100.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0099.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0102.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0101.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0104.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0103.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0105.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0107.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0106.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0108.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0109.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0110.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0111.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0112.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0114.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0113.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0116.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0115.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0117.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0118.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0119.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0120.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0121.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0122.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0123.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0125.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0124.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0126.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0127.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0129.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0128.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0130.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0132.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0131.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0133.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0134.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0135.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0136.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0137.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0138.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0139.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0141.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0140.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0142.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0143.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0144.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0145.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0147.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0146.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0148.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0149.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0151.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0150.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0152.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0153.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0154.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0155.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0156.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0157.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0158.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0159.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0160.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0161.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma/Te-me_0162.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0010.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0011.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0012.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0013.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0014.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0015.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0016.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0017.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0018.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0019.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0020.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0021.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0022.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0023.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0024.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0025.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0026.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0028.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0027.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0029.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0030.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0031.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0032.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0033.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0034.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0035.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0036.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0037.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0038.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0039.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0040.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0042.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0041.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0043.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0044.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0045.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0046.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0047.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0048.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0049.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0050.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0051.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0052.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0053.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0054.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0055.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0056.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0057.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0058.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0059.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0060.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0061.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0063.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0062.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0064.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0065.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0066.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0067.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0068.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0069.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0070.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0071.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0072.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0073.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0074.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0075.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0076.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0077.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0078.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0079.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0080.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0081.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0082.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0083.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0084.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0085.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0086.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0087.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0088.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0089.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0090.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0091.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0092.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0093.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0094.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0095.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0096.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0097.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0098.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0099.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0100.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0101.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0102.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0103.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0104.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0105.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0106.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0107.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0108.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0109.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0110.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0111.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0112.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0113.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0114.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0115.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0116.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0117.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0118.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0119.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0120.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0121.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0122.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0123.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0124.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0125.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0126.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0127.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0128.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0129.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0130.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0131.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0132.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0133.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0134.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0135.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0136.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0137.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0138.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0139.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0140.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0141.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0142.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0143.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0145.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0144.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0146.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0147.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0148.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma/Te-gl_0149.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0010.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0012.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0011.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0013.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0014.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0015.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0017.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0016.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0018.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0019.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0020.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0024.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0022.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0023.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0021.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0027.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0028.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0025.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0026.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0029.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0030.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0031.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0032.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0034.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0035.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0033.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0038.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0039.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0036.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0037.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0040.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0041.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0042.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0044.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0045.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0043.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0047.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0049.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0046.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0048.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0050.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0051.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0052.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0053.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0055.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0054.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0058.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0057.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0056.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0059.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0060.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0062.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0061.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0065.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0063.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0064.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0067.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0066.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0068.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0069.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0073.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0072.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0071.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0070.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0074.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0075.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0077.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0076.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0079.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0078.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0080.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0081.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0083.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0082.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0086.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0084.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0085.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0088.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0087.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0090.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0089.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0093.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0095.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0091.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0092.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0094.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0096.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0097.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0098.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0099.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0100.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0102.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0101.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0103.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0104.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0106.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0105.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0107.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0108.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0109.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0111.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0110.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0114.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0112.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0113.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0115.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0116.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0120.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0118.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0119.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0117.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0122.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0121.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0124.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0125.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0123.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0127.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0128.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0129.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0130.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0126.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0135.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0131.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0133.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0134.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0132.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0138.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0136.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0139.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary/Te-pi_0137.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0010.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0011.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0013.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0012.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0014.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0015.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0016.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0017.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0019.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0018.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0020.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0021.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0022.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0023.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0024.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0026.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0025.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0028.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0027.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0029.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0030.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0031.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0032.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0034.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0033.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0036.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0035.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0038.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0037.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0039.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0041.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0040.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0043.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0042.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0045.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0044.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0046.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0047.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0048.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0051.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0050.jpg
# ...
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0056.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0057.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0058.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0060.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0059.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0061.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0063.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0062.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0065.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0064.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0066.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0068.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0067.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0069.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0070.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0071.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0073.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0072.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0075.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0074.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0076.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0078.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0077.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0080.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0079.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0081.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0082.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0083.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0086.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0085.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0084.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0088.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0087.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0090.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0089.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0091.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0093.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0092.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0096.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0094.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0095.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0097.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0098.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0099.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0101.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0100.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0104.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0103.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0102.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0105.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0106.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0108.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0107.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0109.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0111.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0110.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0113.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0112.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0114.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0116.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0117.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0115.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0118.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0119.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0120.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0122.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0121.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0123.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0124.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0125.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0127.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0126.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0129.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0128.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0130.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0131.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0132.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0133.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0135.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0134.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0136.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0138.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0137.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0141.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0139.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0140.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0142.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0143.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0146.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0145.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0144.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0149.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0148.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0147.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0150.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0151.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0153.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0154.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0152.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0157.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0155.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0156.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0159.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0160.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0158.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0161.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0162.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0163.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0164.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0166.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0165.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0167.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0168.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0170.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0171.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0169.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0172.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0173.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0175.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0176.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0174.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0178.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0179.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0177.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0182.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0180.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0181.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0184.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0185.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0183.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0186.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0187.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0188.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0190.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0189.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0191.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0193.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0192.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0194.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0196.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0195.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0197.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0199.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0198.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0200.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0201.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0202.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0204.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0203.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0206.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0205.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0207.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0208.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0210.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0209.jpg
# Resized image saved to: /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor/Te-no_0211.jpg

# %%
# Function to get image file paths grouped by folder name
def get_image_files_by_folder(directory):
    folder_images = {}

    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tif', '.tiff')):
                # Get the folder name
                folder_name = os.path.basename(root)
                if folder_name not in folder_images:
                    folder_images[folder_name] = []
                # Append the file path to the corresponding folder
                folder_images[folder_name].append(os.path.join(root, file))

    return folder_images

# Import the random module
import random

# Function to display a set of images from each folder
def display_images_by_folder(folder_images, num_images_per_folder=5):
    plt.figure(figsize=(15, 10))

    # Counter for subplot positions
    subplot_index = 1

    for folder_name, image_files in folder_images.items():
        # Randomly select a subset of images from the folder
        selected_files = random.sample(image_files, min(num_images_per_folder, len(image_files)))

        for file_path in selected_files:
            # Load the image
            image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
            if image is None:
                continue

            # Display the image
            plt.subplot(len(folder_images), num_images_per_folder, subplot_index)
            plt.imshow(image, cmap='gray')
            plt.title(folder_name)
            plt.axis('off')
            subplot_index += 1

    plt.tight_layout()
    plt.show()

# Get image files grouped by folder
folder_images = get_image_files_by_folder(input_dir)

# Display images from each folder
display_images_by_folder(folder_images, num_images_per_folder=2)

# %%
import os
from multiprocessing import Pool

# Define noise reduction parameters
gaussian_kernel_size = (5, 5)
median_ksize = 5

# Function to apply noise reduction techniques
def process_image(image_path):
    # Load the image
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    if image is None:
        return

    # Apply Gaussian blur
    blurred_image = cv2.GaussianBlur(image, gaussian_kernel_size, 0)

    # Apply Median filter
    median_filtered_image = cv2.medianBlur(blurred_image, median_ksize)

    # Create output path
    relative_path = os.path.relpath(image_path, test_dir)
    output_path = os.path.join(input_dir, relative_path)
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

    # Save the filtered image
    cv2.imwrite(output_path, median_filtered_image)

# Function to process all images in a directory
def process_directory(test_dir, input_dir):
    # Get a list of all image files
    image_files = [os.path.join(root, file)
                   for root, dirs, files in os.walk(test_dir)
                   for file in files
                   if file.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tif', '.tiff'))]

    # Use multiprocessing to process images in parallel
    with Pool() as pool:
        pool.map(process_image, image_files)


process_directory(test_dir, input_dir)

# %%
import numpy as np
from skimage.feature import hog
from sklearn.preprocessing import StandardScaler
from skimage import io, color
from skimage.transform import resize
import os

def load_images_from_folder(folder_path):
    if not os.path.exists(folder_path):
        raise ValueError(f"Folder does not exist: {folder_path}")

    images = []
    labels = []

    # List subdirectories in the main directory
    subdirectories = [d for d in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, d))]
    print(f"Subdirectories in folder {folder_path}: {subdirectories}")

    if not subdirectories:
        raise ValueError(f"No subdirectories found in folder: {folder_path}")

    # Process each subdirectory
    for subdirectory in subdirectories:
        subfolder_path = os.path.join(folder_path, subdirectory)

        # List files in the subdirectory
        file_list = os.listdir(subfolder_path)
        print(f"Files in subfolder {subfolder_path}: {file_list}")

        if not file_list:
            print(f"No files found in subfolder: {subfolder_path}")
            continue

        # Process each file in the subdirectory
        for filename in file_list:
            img_path = os.path.join(subfolder_path, filename)
            if os.path.isfile(img_path) and filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
                try:
                    img = io.imread(img_path)

                    # Convert grayscale images to RGB
                    if img.ndim == 2:  # Grayscale image
                        img = np.stack([img] * 3, axis=-1)

                    # Resize images to a consistent size (e.g., 256x256)
                    img = resize(img, (256, 256), mode='reflect', anti_aliasing=True)

                    images.append(img)
                    labels.append(subdirectory)  # Use subdirectory name as label
                except Exception as e:
                    print(f"Error loading image {filename}: {e}")
            else:
                print(f"Skipped file (not an image or invalid extension): {filename}")

    if len(images) == 0:
        raise ValueError(f"No valid images found in folder: {folder_path}")

    return np.array(images), np.array(labels)

def preprocess_images(folder_path):
    images, labels = load_images_from_folder(folder_path)

    # Convert RGB images to grayscale for HOG
    images_gray = np.array([color.rgb2gray(img) for img in images])

    # Check if images have the same shape
    img_shapes = [img.shape for img in images_gray]
    print(f"Image shapes: {img_shapes}")  # Debug: Print shapes of images
    if len(set(img_shapes)) > 1:
        raise ValueError("Images have different sizes. Please resize them to a uniform shape.")

    # Extract HOG features
    features = np.array([hog(img, visualize=False) for img in images_gray])

    # Standardize features
    scaler = StandardScaler()
    features_scaled = scaler.fit_transform(features)

    return features_scaled, labels

# Define paths
image_dir = '/content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT'
test_dir = '/content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/INPUT'

# Preprocess training and test data
X_train, y_train = preprocess_images(image_dir)
X_test, y_test = preprocess_images(test_dir)

# Train models as before
# Out:
# Subdirectories in folder /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT: ['meningioma', 'notumor', 'glioma', 'pituitary']
# Files in subfolder /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/meningioma: ['Te-me_0166.jpg', 'Te-meTr_0002.jpg', 'Te-meTr_0001.jpg', 'Te-me_0164.jpg', 'Te-meTr_0000.jpg', 'Te-me_0010.jpg', 'Te-me_0163.jpg', 'Te-me_0165.jpg', 'Te-me_0012.jpg', 'Te-me_0168.jpg', 'Te-me_0170.jpg', 'Te-meTr_0003.jpg', 'Te-me_0011.jpg', 'Te-me_0169.jpg', 'Te-me_0015.jpg', 'Te-me_0178.jpg', 'Te-me_0171.jpg', 'Te-me_0013.jpg', 'Te-me_0173.jpg', 'Te-meTr_0005.jpg', 'Te-me_0016.jpg', 'Te-me_0174.jpg', 'Te-meTr_0009.jpg', 'Te-me_0176.jpg', 'Te-me_0014.jpg', 'Te-me_0175.jpg', 'Te-meTr_0008.jpg', 'Te-me_0172.jpg', 'Te-meTr_0007.jpg', 'Te-meTr_0006.jpg', 'Te-me_0177.jpg', 'Te-meTr_0004.jpg', 'Te-me_0183.jpg', 'Te-me_0180.jpg', 'Te-me_0017.jpg', 'Te-me_0179.jpg', 'Te-me_0032.jpg', 'Te-me_0025.jpg', 'Te-me_0185.jpg', 'Te-me_0023.jpg', 'Te-me_0184.jpg', 'Te-me_0018.jpg', 'Te-me_0186.jpg', 'Te-me_0182.jpg', 'Te-me_0026.jpg', 'Te-me_0019.jpg', 'Te-me_0181.jpg', 'Te-me_0022.jpg', 'Te-me_0021.jpg', 'Te-me_0192.jpg', 'Te-me_0190.jpg', 'Te-me_0027.jpg', 'Te-me_0193.jpg', 'Te-me_0028.jpg', 'Te-me_0191.jpg', 'Te-me_0024.jpg', 'Te-me_0187.jpg', 'Te-me_0031.jpg', 'Te-me_0188.jpg', 'Te-me_0189.jpg', 'Te-me_0020.jpg', 'Te-me_0029.jpg', 'Te-me_0196.jpg', 'Te-me_0030.jpg', 'Te-me_0199.jpg', 'Te-me_0037.jpg', 'Te-me_0198.jpg', 'Te-me_0200.jpg', 'Te-me_0036.jpg', 'Te-me_0033.jpg', 'Te-me_0195.jpg', 'Te-me_0038.jpg', 'Te-me_0035.jpg', 'Te-me_0197.jpg', 'Te-me_0194.jpg', 'Te-me_0040.jpg', 'Te-me_0209.jpg', 'Te-me_0044.jpg', 'Te-me_0205.jpg', 'Te-me_0203.jpg', 'Te-me_0045.jpg', 'Te-me_0039.jpg', 'Te-me_0210.jpg', 'Te-me_0206.jpg', 'Te-me_0034.jpg', 'Te-me_0041.jpg', 'Te-me_0208.jpg', 'Te-me_0043.jpg', 'Te-me_0204.jpg', 'Te-me_0042.jpg', 'Te-me_0046.jpg', 'Te-me_0207.jpg', 'Te-me_0056.jpg', 'Te-me_0201.jpg', 'Te-me_0055.jpg', 'Te-me_0202.jpg', 'Te-me_0219.jpg', 'Te-me_0059.jpg', 'Te-me_0058.jpg', 'Te-me_0220.jpg', 'Te-me_0048.jpg', 'Te-me_0215.jpg', 'Te-me_0211.jpg', 'Te-me_0049.jpg', 'Te-me_0051.jpg', 'Te-me_0221.jpg', 'Te-me_0052.jpg', 'Te-me_0214.jpg', 'Te-me_0047.jpg', 'Te-me_0060.jpg', 'Te-me_0218.jpg', 'Te-me_0053.jpg', 'Te-me_0213.jpg', 'Te-me_0054.jpg', 'Te-me_0057.jpg', 'Te-me_0217.jpg', 'Te-me_0050.jpg', 'Te-me_0212.jpg', 'Te-me_0072.jpg', 'Te-me_0222.jpg', 'Te-me_0061.jpg', 'Te-me_0216.jpg', 'Te-me_0068.jpg', 'Te-me_0230.jpg', 'Te-me_0231.jpg', 'Te-me_0070.jpg', 'Te-me_0071.jpg', 'Te-me_0225.jpg', 'Te-me_0065.jpg', 'Te-me_0226.jpg', 'Te-me_0228.jpg', 'Te-me_0066.jpg', 'Te-me_0069.jpg', 'Te-me_0224.jpg', 'Te-me_0067.jpg', 'Te-me_0227.jpg', 'Te-me_0064.jpg', 'Te-me_0223.jpg', 'Te-me_0063.jpg', 'Te-me_0233.jpg', 'Te-me_0062.jpg', 'Te-me_0232.jpg', 'Te-me_0079.jpg', 'Te-me_0229.jpg', 'Te-me_0073.jpg', 'Te-me_0235.jpg', 'Te-me_0081.jpg', 'Te-me_0242.jpg', 'Te-me_0234.jpg', 'Te-me_0077.jpg', 'Te-me_0074.jpg', 'Te-me_0241.jpg', 'Te-me_0075.jpg', 'Te-me_0080.jpg', 'Te-me_0243.jpg', 'Te-me_0076.jpg', 'Te-me_0239.jpg', 'Te-me_0078.jpg', 'Te-me_0237.jpg', 'Te-me_0082.jpg', 'Te-me_0236.jpg', 'Te-me_0084.jpg', 'Te-me_0083.jpg', 'Te-me_0240.jpg', 'Te-me_0238.jpg', 'Te-me_0090.jpg', 'Te-me_0091.jpg', 'Te-me_0244.jpg', 'Te-me_0085.jpg', 'Te-me_0087.jpg', 'Te-me_0250.jpg', 'Te-me_0088.jpg', 'Te-me_0249.jpg', 'Te-me_0089.jpg', 'Te-me_0251.jpg', 'Te-me_0092.jpg', 'Te-me_0253.jpg', 'Te-me_0097.jpg', 'Te-me_0086.jpg', 'Te-me_0245.jpg', 'Te-me_0096.jpg', 'Te-me_0103.jpg', 'Te-me_0252.jpg', 'Te-me_0102.jpg', 'Te-me_0248.jpg', 'Te-me_0101.jpg', 'Te-me_0246.jpg', 'Te-me_0099.jpg', 'Te-me_0098.jpg', 'Te-me_0247.jpg', 'Te-me_0095.jpg', 'Te-me_0255.jpg', 'Te-me_0093.jpg', 'Te-me_0094.jpg', 'Te-me_0100.jpg', 'Te-me_0258.jpg', 'Te-me_0256.jpg', 'Te-me_0114.jpg', 'Te-me_0254.jpg', 'Te-me_0110.jpg', 'Te-me_0112.jpg', 'Te-me_0257.jpg', 'Te-me_0259.jpg', 'Te-me_0109.jpg', 'Te-me_0106.jpg', 'Te-me_0269.jpg', 'Te-me_0267.jpg', 'Te-me_0264.jpg', 'Te-me_0115.jpg', 'Te-me_0260.jpg', 'Te-me_0107.jpg', 'Te-me_0265.jpg', 'Te-me_0111.jpg', 'Te-me_0113.jpg', 'Te-me_0262.jpg', 'Te-me_0108.jpg', 'Te-m ...
# Files in subfolder /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/notumor: ['Te-no_0250.jpg', 'Te-no_0252.jpg', 'Te-no_0115.jpg', 'Te-no_0113.jpg', 'Te-no_0263.jpg', 'Te-no_0258.jpg', 'Te-no_0112.jpg', 'Te-no_0129.jpg', 'Te-no_0260.jpg', 'Te-no_0257.jpg', 'Te-no_0128.jpg', 'Te-no_0259.jpg', 'Te-no_0124.jpg', 'Te-no_0261.jpg', 'Te-no_0122.jpg', 'Te-no_0262.jpg', 'Te-no_0264.jpg', 'Te-no_0123.jpg', 'Te-no_0130.jpg', 'Te-no_0267.jpg', 'Te-no_0266.jpg', 'Te-no_0133.jpg', 'Te-no_0271.jpg', 'Te-no_0135.jpg', 'Te-no_0269.jpg', 'Te-no_0265.jpg', 'Te-no_0136.jpg', 'Te-no_0131.jpg', 'Te-no_0268.jpg', 'Te-no_0270.jpg', 'Te-no_0132.jpg', 'Te-no_0137.jpg', 'Te-no_0272.jpg', 'Te-no_0144.jpg', 'Te-no_0274.jpg', 'Te-no_0139.jpg', 'Te-no_0282.jpg', 'Te-no_0278.jpg', 'Te-no_0279.jpg', 'Te-no_0273.jpg', 'Te-no_0275.jpg', 'Te-no_0277.jpg', 'Te-no_0276.jpg', 'Te-no_0143.jpg', 'Te-no_0146.jpg', 'Te-no_0280.jpg', 'Te-no_0289.jpg', 'Te-no_0281.jpg', 'Te-no_0149.jpg', 'Te-no_0155.jpg', 'Te-no_0293.jpg', 'Te-no_0284.jpg', 'Te-no_0147.jpg', 'Te-no_0292.jpg', 'Te-no_0154.jpg', 'Te-no_0283.jpg', 'Te-no_0291.jpg', 'Te-no_0152.jpg', 'Te-no_0288.jpg', 'Te-no_0151.jpg', 'Te-no_0290.jpg', 'Te-no_0287.jpg', 'Te-no_0285.jpg', 'Te-no_0286.jpg', 'Te-no_0302.jpg', 'Te-no_0301.jpg', 'Te-no_0295.jpg', 'Te-no_0161.jpg', 'Te-no_0297.jpg', 'Te-no_0300.jpg', 'Te-no_0160.jpg', 'Te-no_0156.jpg', 'Te-no_0299.jpg', 'Te-no_0294.jpg', 'Te-no_0159.jpg', 'Te-no_0298.jpg', 'Te-no_0296.jpg', 'Te-no_0170.jpg', 'Te-no_0166.jpg', 'Te-no_0310.jpg', 'Te-no_0164.jpg', 'Te-no_0304.jpg', 'Te-no_0169.jpg', 'Te-no_0305.jpg', 'Te-no_0303.jpg', 'Te-no_0309.jpg', 'Te-no_0308.jpg', 'Te-no_0313.jpg', 'Te-no_0171.jpg', 'Te-no_0316.jpg', 'Te-no_0162.jpg', 'Te-no_0167.jpg', 'Te-no_0173.jpg', 'Te-no_0312.jpg', 'Te-no_0179.jpg', 'Te-no_0177.jpg', 'Te-no_0318.jpg', 'Te-no_0319.jpg', 'Te-no_0317.jpg', 'Te-no_0181.jpg', 'Te-no_0180.jpg', 'Te-no_0315.jpg', 'Te-no_0175.jpg', 'Te-no_0314.jpg', 'Te-no_0172.jpg', 'Te-no_0328.jpg', 'Te-no_0176.jpg', 'Te-no_0322.jpg', 'Te-no_0174.jpg', 'Te-no_0178.jpg', 'Te-no_0324.jpg', 'Te-no_0183.jpg', 'Te-no_0329.jpg', 'Te-no_0330.jpg', 'Te-no_0184.jpg', 'Te-no_0182.jpg', 'Te-no_0326.jpg', 'Te-no_0190.jpg', 'Te-no_0346.jpg', 'Te-no_0348.jpg', 'Te-no_0321.jpg', 'Te-no_0356.jpg', 'Te-no_0353.jpg', 'Te-no_0354.jpg', 'Te-no_0358.jpg', 'Te-no_0360.jpg', 'Te-no_0355.jpg', 'Te-no_0333.jpg', 'Te-no_0352.jpg', 'Te-no_0341.jpg', 'Te-no_0357.jpg', 'Te-no_0359.jpg', 'Te-no_0339.jpg', 'Te-no_0364.jpg', 'Te-no_0337.jpg', 'Te-no_0366.jpg', 'Te-no_0340.jpg', 'Te-no_0350.jpg', 'Te-no_0361.jpg', 'Te-no_0369.jpg', 'Te-no_0368.jpg', 'Te-no_0362.jpg', 'Te-no_0343.jpg', 'Te-no_0371.jpg', 'Te-no_0345.jpg', 'Te-no_0370.jpg', 'Te-no_0342.jpg', 'Te-no_0365.jpg', 'Te-no_0351.jpg', 'Te-no_0367.jpg', 'Te-no_0363.jpg', 'Te-no_0372.jpg', 'Te-no_0379.jpg', 'Te-no_0375.jpg', 'Te-no_0382.jpg', 'Te-no_0377.jpg', 'Te-no_0378.jpg', 'Te-no_0384.jpg', 'Te-no_0383.jpg', 'Te-no_0376.jpg', 'Te-no_0380.jpg', 'Te-no_0381.jpg', 'Te-no_0373.jpg', 'Te-no_0374.jpg', 'Te-no_0393.jpg', 'Te-no_0396.jpg', 'Te-no_0394.jpg', 'Te-no_0397.jpg', 'Te-no_0386.jpg', 'Te-no_0385.jpg', 'Te-no_0392.jpg', 'Te-no_0395.jpg', 'Te-no_0389.jpg', 'Te-no_0388.jpg', 'Te-no_0387.jpg', 'Te-no_0390.jpg', 'Te-no_0403.jpg', 'Te-no_0399.jpg', 'Te-no_0404.jpg', 'Te-no_0391.jpg', 'Te-no_0398.jpg', 'Te-no_0402.jpg', 'Te-no_0400.jpg', 'Te-no_0401.jpg', 'Te-noTr_0001.jpg', 'Te-noTr_0000.jpg', 'Te-noTr_0007.jpg', 'Te-noTr_0004.jpg', 'Te-noTr_0006.jpg', 'Te-noTr_0005.jpg', 'Te-noTr_0002.jpg', 'Te-noTr_0008.jpg', 'Te-noTr_0003.jpg', 'Te-no_0014.jpg', 'Te-no_0024.jpg', 'Te-no_0022.jpg', 'Te-noTr_0009.jpg', 'Te-no_0019.jpg', 'Te-no_0012.jpg', 'Te-no_0023.jpg', 'Te-no_0016.jpg', 'Te-no_0029.jpg', 'Te-no_0010.jpg', 'Te-no_0013.jpg', 'Te-no_0031.jpg', 'Te-no_0028.jpg', 'Te-no_0011.jpg', 'Te-no_0026.jpg', 'Te-no_0017.jpg', 'Te-no_0030.jpg', 'Te-no_0015.jpg', 'Te-no_0027.jpg', 'Te-no_0025.jpg', 'Te-no_0032.jpg', 'Te-no_0034.jpg', 'Te-no_0021.jpg', 'Te-no_0 ...
# Files in subfolder /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/glioma: ['Te-gl_0105.jpg', 'Te-gl_0100.jpg', 'Te-gl_0106.jpg', 'Te-gl_0112.jpg', 'Te-gl_0109.jpg', 'Te-gl_0123.jpg', 'Te-gl_0117.jpg', 'Te-gl_0122.jpg', 'Te-gl_0116.jpg', 'Te-gl_0121.jpg', 'Te-gl_0115.jpg', 'Te-gl_0120.jpg', 'Te-gl_0127.jpg', 'Te-gl_0119.jpg', 'Te-gl_0118.jpg', 'Te-gl_0125.jpg', 'Te-gl_0114.jpg', 'Te-gl_0124.jpg', 'Te-gl_0126.jpg', 'Te-gl_0132.jpg', 'Te-gl_0131.jpg', 'Te-gl_0135.jpg', 'Te-gl_0136.jpg', 'Te-gl_0139.jpg', 'Te-gl_0130.jpg', 'Te-gl_0134.jpg', 'Te-gl_0140.jpg', 'Te-gl_0141.jpg', 'Te-gl_0128.jpg', 'Te-gl_0137.jpg', 'Te-gl_0129.jpg', 'Te-gl_0142.jpg', 'Te-gl_0138.jpg', 'Te-gl_0133.jpg', 'Te-gl_0143.jpg', 'Te-gl_0151.jpg', 'Te-gl_0150.jpg', 'Te-gl_0144.jpg', 'Te-glTr_0000.jpg', 'Te-gl_0154.jpg', 'Te-gl_0146.jpg', 'Te-glTr_0003.jpg', 'Te-glTr_0004.jpg', 'Te-glTr_0002.jpg', 'Te-gl_0145.jpg', 'Te-gl_0148.jpg', 'Te-gl_0147.jpg', 'Te-glTr_0001.jpg', 'Te-gl_0011.jpg', 'Te-gl_0149.jpg', 'Te-gl_0153.jpg', 'Te-gl_0013.jpg', 'Te-glTr_0005.jpg', 'Te-gl_0156.jpg', 'Te-gl_0157.jpg', 'Te-glTr_0007.jpg', 'Te-gl_0152.jpg', 'Te-gl_0010.jpg', 'Te-glTr_0008.jpg', 'Te-gl_0155.jpg', 'Te-gl_0163.jpg', 'Te-gl_0012.jpg', 'Te-glTr_0006.jpg', 'Te-gl_0162.jpg', 'Te-glTr_0009.jpg', 'Te-gl_0158.jpg', 'Te-gl_0016.jpg', 'Te-gl_0170.jpg', 'Te-gl_0019.jpg', 'Te-gl_0018.jpg', 'Te-gl_0164.jpg', 'Te-gl_0160.jpg', 'Te-gl_0014.jpg', 'Te-gl_0165.jpg', 'Te-gl_0171.jpg', 'Te-gl_0015.jpg', 'Te-gl_0017.jpg', 'Te-gl_0168.jpg', 'Te-gl_0020.jpg', 'Te-gl_0024.jpg', 'Te-gl_0159.jpg', 'Te-gl_0166.jpg', 'Te-gl_0167.jpg', 'Te-gl_0023.jpg', 'Te-gl_0027.jpg', 'Te-gl_0161.jpg', 'Te-gl_0169.jpg', 'Te-gl_0021.jpg', 'Te-gl_0022.jpg', 'Te-gl_0172.jpg', 'Te-gl_0025.jpg', 'Te-gl_0181.jpg', 'Te-gl_0026.jpg', 'Te-gl_0184.jpg', 'Te-gl_0036.jpg', 'Te-gl_0176.jpg', 'Te-gl_0028.jpg', 'Te-gl_0174.jpg', 'Te-gl_0035.jpg', 'Te-gl_0185.jpg', 'Te-gl_0041.jpg', 'Te-gl_0175.jpg', 'Te-gl_0038.jpg', 'Te-gl_0183.jpg', 'Te-gl_0029.jpg', 'Te-gl_0186.jpg', 'Te-gl_0037.jpg', 'Te-gl_0173.jpg', 'Te-gl_0040.jpg', 'Te-gl_0180.jpg', 'Te-gl_0032.jpg', 'Te-gl_0179.jpg', 'Te-gl_0034.jpg', 'Te-gl_0177.jpg', 'Te-gl_0039.jpg', 'Te-gl_0033.jpg', 'Te-gl_0182.jpg', 'Te-gl_0030.jpg', 'Te-gl_0178.jpg', 'Te-gl_0195.jpg', 'Te-gl_0031.jpg', 'Te-gl_0048.jpg', 'Te-gl_0190.jpg', 'Te-gl_0054.jpg', 'Te-gl_0199.jpg', 'Te-gl_0052.jpg', 'Te-gl_0188.jpg', 'Te-gl_0047.jpg', 'Te-gl_0196.jpg', 'Te-gl_0045.jpg', 'Te-gl_0197.jpg', 'Te-gl_0049.jpg', 'Te-gl_0198.jpg', 'Te-gl_0193.jpg', 'Te-gl_0050.jpg', 'Te-gl_0043.jpg', 'Te-gl_0187.jpg', 'Te-gl_0053.jpg', 'Te-gl_0191.jpg', 'Te-gl_0042.jpg', 'Te-gl_0200.jpg', 'Te-gl_0046.jpg', 'Te-gl_0189.jpg', 'Te-gl_0051.jpg', 'Te-gl_0194.jpg', 'Te-gl_0044.jpg', 'Te-gl_0063.jpg', 'Te-gl_0192.jpg', 'Te-gl_0204.jpg', 'Te-gl_0069.jpg', 'Te-gl_0208.jpg', 'Te-gl_0213.jpg', 'Te-gl_0210.jpg', 'Te-gl_0062.jpg', 'Te-gl_0067.jpg', 'Te-gl_0055.jpg', 'Te-gl_0212.jpg', 'Te-gl_0056.jpg', 'Te-gl_0214.jpg', 'Te-gl_0202.jpg', 'Te-gl_0058.jpg', 'Te-gl_0064.jpg', 'Te-gl_0201.jpg', 'Te-gl_0065.jpg', 'Te-gl_0203.jpg', 'Te-gl_0209.jpg', 'Te-gl_0057.jpg', 'Te-gl_0061.jpg', 'Te-gl_0206.jpg', 'Te-gl_0211.jpg', 'Te-gl_0059.jpg', 'Te-gl_0068.jpg', 'Te-gl_0205.jpg', 'Te-gl_0060.jpg', 'Te-gl_0207.jpg', 'Te-gl_0228.jpg', 'Te-gl_0066.jpg', 'Te-gl_0224.jpg', 'Te-gl_0080.jpg', 'Te-gl_0077.jpg', 'Te-gl_0222.jpg', 'Te-gl_0227.jpg', 'Te-gl_0076.jpg', 'Te-gl_0079.jpg', 'Te-gl_0221.jpg', 'Te-gl_0078.jpg', 'Te-gl_0223.jpg', 'Te-gl_0075.jpg', 'Te-gl_0230.jpg', 'Te-gl_0081.jpg', 'Te-gl_0218.jpg', 'Te-gl_0084.jpg', 'Te-gl_0219.jpg', 'Te-gl_0074.jpg', 'Te-gl_0220.jpg', 'Te-gl_0226.jpg', 'Te-gl_0082.jpg', 'Te-gl_0083.jpg', 'Te-gl_0225.jpg', 'Te-gl_0072.jpg', 'Te-gl_0070.jpg', 'Te-gl_0215.jpg', 'Te-gl_0217.jpg', 'Te-gl_0229.jpg', 'Te-gl_0073.jpg', 'Te-gl_0071.jpg', 'Te-gl_0216.jpg', 'Te-gl_0089.jpg', 'Te-gl_0237.jpg', 'Te-gl_0087.jpg', 'Te-gl_0240.jpg', 'Te-gl_0243.jpg', 'Te-gl_0085.jpg', 'Te-gl_0098.jpg', 'Te-gl_0242.jpg', 'Te-gl_0093.jpg', 'Te-gl_02 ...
# Files in subfolder /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/OUTPUT/pituitary: ['Te-pi_0131.jpg', 'Te-pi_0133.jpg', 'Te-pi_0150.jpg', 'Te-pi_0140.jpg', 'Te-pi_0139.jpg', 'Te-pi_0141.jpg', 'Te-piTr_0001.jpg', 'Te-pi_0147.jpg', 'Te-pi_0145.jpg', 'Te-piTr_0003.jpg', 'Te-piTr_0002.jpg', 'Te-piTr_0000.jpg', 'Te-pi_0144.jpg', 'Te-pi_0149.jpg', 'Te-piTr_0009.jpg', 'Te-pi_0011.jpg', 'Te-pi_0142.jpg', 'Te-pi_0148.jpg', 'Te-pi_0014.jpg', 'Te-pi_0146.jpg', 'Te-pi_0143.jpg', 'Te-pi_0013.jpg', 'Te-pi_0155.jpg', 'Te-piTr_0007.jpg', 'Te-pi_0012.jpg', 'Te-pi_0158.jpg', 'Te-pi_0010.jpg', 'Te-pi_0157.jpg', 'Te-pi_0156.jpg', 'Te-piTr_0006.jpg', 'Te-pi_0154.jpg', 'Te-piTr_0004.jpg', 'Te-piTr_0008.jpg', 'Te-pi_0151.jpg', 'Te-piTr_0005.jpg', 'Te-pi_0153.jpg', 'Te-pi_0016.jpg', 'Te-pi_0152.jpg', 'Te-pi_0162.jpg', 'Te-pi_0019.jpg', 'Te-pi_0024.jpg', 'Te-pi_0021.jpg', 'Te-pi_0159.jpg', 'Te-pi_0017.jpg', 'Te-pi_0160.jpg', 'Te-pi_0015.jpg', 'Te-pi_0161.jpg', 'Te-pi_0018.jpg', 'Te-pi_0163.jpg', 'Te-pi_0167.jpg', 'Te-pi_0025.jpg', 'Te-pi_0166.jpg', 'Te-pi_0022.jpg', 'Te-pi_0020.jpg', 'Te-pi_0168.jpg', 'Te-pi_0164.jpg', 'Te-pi_0023.jpg', 'Te-pi_0030.jpg', 'Te-pi_0165.jpg', 'Te-pi_0031.jpg', 'Te-pi_0169.jpg', 'Te-pi_0179.jpg', 'Te-pi_0027.jpg', 'Te-pi_0028.jpg', 'Te-pi_0175.jpg', 'Te-pi_0177.jpg', 'Te-pi_0033.jpg', 'Te-pi_0173.jpg', 'Te-pi_0026.jpg', 'Te-pi_0172.jpg', 'Te-pi_0032.jpg', 'Te-pi_0029.jpg', 'Te-pi_0171.jpg', 'Te-pi_0036.jpg', 'Te-pi_0174.jpg', 'Te-pi_0034.jpg', 'Te-pi_0178.jpg', 'Te-pi_0037.jpg', 'Te-pi_0035.jpg', 'Te-pi_0176.jpg', 'Te-pi_0170.jpg', 'Te-pi_0038.jpg', 'Te-pi_0185.jpg', 'Te-pi_0039.jpg', 'Te-pi_0188.jpg', 'Te-pi_0044.jpg', 'Te-pi_0182.jpg', 'Te-pi_0043.jpg', 'Te-pi_0181.jpg', 'Te-pi_0040.jpg', 'Te-pi_0183.jpg', 'Te-pi_0045.jpg', 'Te-pi_0184.jpg', 'Te-pi_0046.jpg', 'Te-pi_0180.jpg', 'Te-pi_0187.jpg', 'Te-pi_0041.jpg', 'Te-pi_0042.jpg', 'Te-pi_0186.jpg', 'Te-pi_0193.jpg', 'Te-pi_0054.jpg', 'Te-pi_0191.jpg', 'Te-pi_0048.jpg', 'Te-pi_0053.jpg', 'Te-pi_0192.jpg', 'Te-pi_0189.jpg', 'Te-pi_0050.jpg', 'Te-pi_0051.jpg', 'Te-pi_0190.jpg', 'Te-pi_0052.jpg', 'Te-pi_0198.jpg', 'Te-pi_0047.jpg', 'Te-pi_0195.jpg', 'Te-pi_0049.jpg', 'Te-pi_0200.jpg', 'Te-pi_0196.jpg', 'Te-pi_0055.jpg', 'Te-pi_0059.jpg', 'Te-pi_0201.jpg', 'Te-pi_0060.jpg', 'Te-pi_0199.jpg', 'Te-pi_0197.jpg', 'Te-pi_0061.jpg', 'Te-pi_0057.jpg', 'Te-pi_0194.jpg', 'Te-pi_0058.jpg', 'Te-pi_0211.jpg', 'Te-pi_0056.jpg', 'Te-pi_0208.jpg', 'Te-pi_0067.jpg', 'Te-pi_0203.jpg', 'Te-pi_0063.jpg', 'Te-pi_0065.jpg', 'Te-pi_0209.jpg', 'Te-pi_0068.jpg', 'Te-pi_0207.jpg', 'Te-pi_0069.jpg', 'Te-pi_0064.jpg', 'Te-pi_0206.jpg', 'Te-pi_0062.jpg', 'Te-pi_0205.jpg', 'Te-pi_0204.jpg', 'Te-pi_0066.jpg', 'Te-pi_0070.jpg', 'Te-pi_0072.jpg', 'Te-pi_0210.jpg', 'Te-pi_0202.jpg', 'Te-pi_0076.jpg', 'Te-pi_0213.jpg', 'Te-pi_0079.jpg', 'Te-pi_0077.jpg', 'Te-pi_0216.jpg', 'Te-pi_0074.jpg', 'Te-pi_0218.jpg', 'Te-pi_0214.jpg', 'Te-pi_0075.jpg', 'Te-pi_0078.jpg', 'Te-pi_0215.jpg', 'Te-pi_0073.jpg', 'Te-pi_0071.jpg', 'Te-pi_0217.jpg', 'Te-pi_0080.jpg', 'Te-pi_0212.jpg', 'Te-pi_0083.jpg', 'Te-pi_0081.jpg', 'Te-pi_0082.jpg', 'Te-pi_0222.jpg', 'Te-pi_0084.jpg', 'Te-pi_0088.jpg', 'Te-pi_0221.jpg', 'Te-pi_0093.jpg', 'Te-pi_0091.jpg', 'Te-pi_0219.jpg', 'Te-pi_0087.jpg', 'Te-pi_0223.jpg', 'Te-pi_0089.jpg', 'Te-pi_0224.jpg', 'Te-pi_0092.jpg', 'Te-pi_0220.jpg', 'Te-pi_0090.jpg', 'Te-pi_0230.jpg', 'Te-pi_0231.jpg', 'Te-pi_0085.jpg', 'Te-pi_0086.jpg', 'Te-pi_0232.jpg', 'Te-pi_0096.jpg', 'Te-pi_0229.jpg', 'Te-pi_0098.jpg', 'Te-pi_0226.jpg', 'Te-pi_0227.jpg', 'Te-pi_0099.jpg', 'Te-pi_0095.jpg', 'Te-pi_0228.jpg', 'Te-pi_0225.jpg', 'Te-pi_0094.jpg', 'Te-pi_0102.jpg', 'Te-pi_0097.jpg', 'Te-pi_0233.jpg', 'Te-pi_0101.jpg', 'Te-pi_0234.jpg', 'Te-pi_0107.jpg', 'Te-pi_0236.jpg', 'Te-pi_0106.jpg', 'Te-pi_0109.jpg', 'Te-pi_0100.jpg', 'Te-pi_0237.jpg', 'Te-pi_0103.jpg', 'Te-pi_0235.jpg', 'Te-pi_0108.jpg', 'Te-pi_0239.jpg', 'Te-pi_0238.jpg', 'Te-pi_0104.jpg', 'Te-pi_0241.jpg', 'Te-pi_0105.jpg', 'Te-pi_0110.jpg', 'Te-pi_0245.jpg', 'Te-pi ...
# Image shapes: [(256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), ( ...
# Subdirectories in folder /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/INPUT: ['meningioma', 'glioma', 'pituitary', 'notumor']
# Files in subfolder /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/INPUT/meningioma: ['Te-me_0089.jpg', 'Te-me_0010.jpg', 'Te-me_0012.jpg', 'Te-me_0094.jpg', 'Te-me_0090.jpg', 'Te-me_0013.jpg', 'Te-me_0093.jpg', 'Te-me_0092.jpg', 'Te-me_0011.jpg', 'Te-me_0014.jpg', 'Te-me_0095.jpg', 'Te-me_0091.jpg', 'Te-me_0015.jpg', 'Te-me_0097.jpg', 'Te-me_0096.jpg', 'Te-me_0016.jpg', 'Te-me_0100.jpg', 'Te-me_0098.jpg', 'Te-me_0017.jpg', 'Te-me_0018.jpg', 'Te-me_0099.jpg', 'Te-me_0102.jpg', 'Te-me_0019.jpg', 'Te-me_0020.jpg', 'Te-me_0105.jpg', 'Te-me_0103.jpg', 'Te-me_0101.jpg', 'Te-me_0104.jpg', 'Te-me_0021.jpg', 'Te-me_0107.jpg', 'Te-me_0022.jpg', 'Te-me_0106.jpg', 'Te-me_0108.jpg', 'Te-me_0109.jpg', 'Te-me_0023.jpg', 'Te-me_0110.jpg', 'Te-me_0111.jpg', 'Te-me_0024.jpg', 'Te-me_0112.jpg', 'Te-me_0025.jpg', 'Te-me_0114.jpg', 'Te-me_0026.jpg', 'Te-me_0113.jpg', 'Te-me_0027.jpg', 'Te-me_0116.jpg', 'Te-me_0029.jpg', 'Te-me_0115.jpg', 'Te-me_0028.jpg', 'Te-me_0117.jpg', 'Te-me_0030.jpg', 'Te-me_0118.jpg', 'Te-me_0031.jpg', 'Te-me_0119.jpg', 'Te-me_0032.jpg', 'Te-me_0033.jpg', 'Te-me_0120.jpg', 'Te-me_0034.jpg', 'Te-me_0121.jpg', 'Te-me_0036.jpg', 'Te-me_0035.jpg', 'Te-me_0037.jpg', 'Te-me_0122.jpg', 'Te-me_0038.jpg', 'Te-me_0123.jpg', 'Te-me_0039.jpg', 'Te-me_0040.jpg', 'Te-me_0125.jpg', 'Te-me_0124.jpg', 'Te-me_0041.jpg', 'Te-me_0042.jpg', 'Te-me_0126.jpg', 'Te-me_0043.jpg', 'Te-me_0044.jpg', 'Te-me_0127.jpg', 'Te-me_0045.jpg', 'Te-me_0129.jpg', 'Te-me_0046.jpg', 'Te-me_0128.jpg', 'Te-me_0047.jpg', 'Te-me_0048.jpg', 'Te-me_0130.jpg', 'Te-me_0049.jpg', 'Te-me_0132.jpg', 'Te-me_0050.jpg', 'Te-me_0051.jpg', 'Te-me_0131.jpg', 'Te-me_0052.jpg', 'Te-me_0133.jpg', 'Te-me_0053.jpg', 'Te-me_0134.jpg', 'Te-me_0054.jpg', 'Te-me_0135.jpg', 'Te-me_0055.jpg', 'Te-me_0136.jpg', 'Te-me_0137.jpg', 'Te-me_0057.jpg', 'Te-me_0056.jpg', 'Te-me_0138.jpg', 'Te-me_0058.jpg', 'Te-me_0139.jpg', 'Te-me_0059.jpg', 'Te-me_0060.jpg', 'Te-me_0141.jpg', 'Te-me_0061.jpg', 'Te-me_0140.jpg', 'Te-me_0062.jpg', 'Te-me_0142.jpg', 'Te-me_0143.jpg', 'Te-me_0063.jpg', 'Te-me_0065.jpg', 'Te-me_0144.jpg', 'Te-me_0064.jpg', 'Te-me_0145.jpg', 'Te-me_0147.jpg', 'Te-me_0066.jpg', 'Te-me_0146.jpg', 'Te-me_0148.jpg', 'Te-me_0067.jpg', 'Te-me_0149.jpg', 'Te-me_0068.jpg', 'Te-me_0151.jpg', 'Te-me_0069.jpg', 'Te-me_0070.jpg', 'Te-me_0150.jpg', 'Te-me_0071.jpg', 'Te-me_0072.jpg', 'Te-me_0153.jpg', 'Te-me_0152.jpg', 'Te-me_0073.jpg', 'Te-me_0154.jpg', 'Te-me_0074.jpg', 'Te-me_0155.jpg', 'Te-me_0075.jpg', 'Te-me_0077.jpg', 'Te-me_0156.jpg', 'Te-me_0076.jpg', 'Te-me_0157.jpg', 'Te-me_0078.jpg', 'Te-me_0158.jpg', 'Te-me_0079.jpg', 'Te-me_0159.jpg', 'Te-me_0080.jpg', 'Te-me_0081.jpg', 'Te-me_0160.jpg', 'Te-me_0082.jpg', 'Te-me_0161.jpg', 'Te-me_0083.jpg', 'Te-me_0162.jpg', 'Te-me_0084.jpg', 'Te-me_0085.jpg', 'Te-me_0086.jpg', 'Te-me_0087.jpg', 'Te-me_0088.jpg']
# Files in subfolder /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/INPUT/glioma: ['Te-gl_0010.jpg', 'Te-gl_0011.jpg', 'Te-gl_0012.jpg', 'Te-gl_0015.jpg', 'Te-gl_0013.jpg', 'Te-gl_0016.jpg', 'Te-gl_0014.jpg', 'Te-gl_0017.jpg', 'Te-gl_0094.jpg', 'Te-gl_0018.jpg', 'Te-gl_0095.jpg', 'Te-gl_0019.jpg', 'Te-gl_0096.jpg', 'Te-gl_0097.jpg', 'Te-gl_0020.jpg', 'Te-gl_0021.jpg', 'Te-gl_0098.jpg', 'Te-gl_0099.jpg', 'Te-gl_0022.jpg', 'Te-gl_0023.jpg', 'Te-gl_0100.jpg', 'Te-gl_0101.jpg', 'Te-gl_0024.jpg', 'Te-gl_0025.jpg', 'Te-gl_0102.jpg', 'Te-gl_0026.jpg', 'Te-gl_0103.jpg', 'Te-gl_0028.jpg', 'Te-gl_0027.jpg', 'Te-gl_0104.jpg', 'Te-gl_0105.jpg', 'Te-gl_0029.jpg', 'Te-gl_0106.jpg', 'Te-gl_0030.jpg', 'Te-gl_0107.jpg', 'Te-gl_0108.jpg', 'Te-gl_0031.jpg', 'Te-gl_0032.jpg', 'Te-gl_0109.jpg', 'Te-gl_0033.jpg', 'Te-gl_0110.jpg', 'Te-gl_0034.jpg', 'Te-gl_0035.jpg', 'Te-gl_0111.jpg', 'Te-gl_0112.jpg', 'Te-gl_0036.jpg', 'Te-gl_0113.jpg', 'Te-gl_0037.jpg', 'Te-gl_0114.jpg', 'Te-gl_0038.jpg', 'Te-gl_0115.jpg', 'Te-gl_0039.jpg', 'Te-gl_0116.jpg', 'Te-gl_0042.jpg', 'Te-gl_0117.jpg', 'Te-gl_0040.jpg', 'Te-gl_0118.jpg', 'Te-gl_0041.jpg', 'Te-gl_0119.jpg', 'Te-gl_0043.jpg', 'Te-gl_0044.jpg', 'Te-gl_0120.jpg', 'Te-gl_0121.jpg', 'Te-gl_0045.jpg', 'Te-gl_0046.jpg', 'Te-gl_0122.jpg', 'Te-gl_0123.jpg', 'Te-gl_0047.jpg', 'Te-gl_0124.jpg', 'Te-gl_0048.jpg', 'Te-gl_0049.jpg', 'Te-gl_0125.jpg', 'Te-gl_0126.jpg', 'Te-gl_0050.jpg', 'Te-gl_0127.jpg', 'Te-gl_0051.jpg', 'Te-gl_0052.jpg', 'Te-gl_0128.jpg', 'Te-gl_0129.jpg', 'Te-gl_0053.jpg', 'Te-gl_0130.jpg', 'Te-gl_0054.jpg', 'Te-gl_0131.jpg', 'Te-gl_0055.jpg', 'Te-gl_0132.jpg', 'Te-gl_0056.jpg', 'Te-gl_0133.jpg', 'Te-gl_0057.jpg', 'Te-gl_0134.jpg', 'Te-gl_0058.jpg', 'Te-gl_0135.jpg', 'Te-gl_0059.jpg', 'Te-gl_0136.jpg', 'Te-gl_0060.jpg', 'Te-gl_0137.jpg', 'Te-gl_0138.jpg', 'Te-gl_0061.jpg', 'Te-gl_0063.jpg', 'Te-gl_0139.jpg', 'Te-gl_0140.jpg', 'Te-gl_0062.jpg', 'Te-gl_0064.jpg', 'Te-gl_0141.jpg', 'Te-gl_0142.jpg', 'Te-gl_0065.jpg', 'Te-gl_0066.jpg', 'Te-gl_0143.jpg', 'Te-gl_0067.jpg', 'Te-gl_0145.jpg', 'Te-gl_0068.jpg', 'Te-gl_0144.jpg', 'Te-gl_0069.jpg', 'Te-gl_0147.jpg', 'Te-gl_0146.jpg', 'Te-gl_0070.jpg', 'Te-gl_0071.jpg', 'Te-gl_0148.jpg', 'Te-gl_0072.jpg', 'Te-gl_0149.jpg', 'Te-gl_0073.jpg', 'Te-gl_0074.jpg', 'Te-gl_0076.jpg', 'Te-gl_0075.jpg', 'Te-gl_0077.jpg', 'Te-gl_0078.jpg', 'Te-gl_0080.jpg', 'Te-gl_0079.jpg', 'Te-gl_0081.jpg', 'Te-gl_0082.jpg', 'Te-gl_0083.jpg', 'Te-gl_0084.jpg', 'Te-gl_0085.jpg', 'Te-gl_0086.jpg', 'Te-gl_0087.jpg', 'Te-gl_0088.jpg', 'Te-gl_0089.jpg', 'Te-gl_0090.jpg', 'Te-gl_0091.jpg', 'Te-gl_0092.jpg', 'Te-gl_0093.jpg', '454072_Martodipoetro_Final_Thesis.pdf', 'KNN model.pdf', '978-3-031-19836-6.pdf']
# Skipped file (not an image or invalid extension): 454072_Martodipoetro_Final_Thesis.pdf
# Skipped file (not an image or invalid extension): KNN model.pdf
# Skipped file (not an image or invalid extension): 978-3-031-19836-6.pdf
# Files in subfolder /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/INPUT/pituitary: ['Te-pi_0010.jpg', 'Te-pi_0012.jpg', 'Te-pi_0011.jpg', 'Te-pi_0013.jpg', 'Te-pi_0014.jpg', 'Te-pi_0015.jpg', 'Te-pi_0017.jpg', 'Te-pi_0016.jpg', 'Te-pi_0018.jpg', 'Te-pi_0019.jpg', 'Te-pi_0020.jpg', 'Te-pi_0024.jpg', 'Te-pi_0022.jpg', 'Te-pi_0023.jpg', 'Te-pi_0021.jpg', 'Te-pi_0027.jpg', 'Te-pi_0028.jpg', 'Te-pi_0025.jpg', 'Te-pi_0026.jpg', 'Te-pi_0029.jpg', 'Te-pi_0034.jpg', 'Te-pi_0030.jpg', 'Te-pi_0035.jpg', 'Te-pi_0031.jpg', 'Te-pi_0033.jpg', 'Te-pi_0032.jpg', 'Te-pi_0038.jpg', 'Te-pi_0114.jpg', 'Te-pi_0039.jpg', 'Te-pi_0112.jpg', 'Te-pi_0113.jpg', 'Te-pi_0036.jpg', 'Te-pi_0115.jpg', 'Te-pi_0037.jpg', 'Te-pi_0116.jpg', 'Te-pi_0040.jpg', 'Te-pi_0120.jpg', 'Te-pi_0041.jpg', 'Te-pi_0042.jpg', 'Te-pi_0118.jpg', 'Te-pi_0044.jpg', 'Te-pi_0119.jpg', 'Te-pi_0045.jpg', 'Te-pi_0117.jpg', 'Te-pi_0043.jpg', 'Te-pi_0122.jpg', 'Te-pi_0047.jpg', 'Te-pi_0121.jpg', 'Te-pi_0049.jpg', 'Te-pi_0124.jpg', 'Te-pi_0046.jpg', 'Te-pi_0125.jpg', 'Te-pi_0048.jpg', 'Te-pi_0050.jpg', 'Te-pi_0123.jpg', 'Te-pi_0127.jpg', 'Te-pi_0128.jpg', 'Te-pi_0051.jpg', 'Te-pi_0052.jpg', 'Te-pi_0053.jpg', 'Te-pi_0129.jpg', 'Te-pi_0130.jpg', 'Te-pi_0055.jpg', 'Te-pi_0126.jpg', 'Te-pi_0054.jpg', 'Te-pi_0135.jpg', 'Te-pi_0058.jpg', 'Te-pi_0131.jpg', 'Te-pi_0057.jpg', 'Te-pi_0133.jpg', 'Te-pi_0056.jpg', 'Te-pi_0134.jpg', 'Te-pi_0059.jpg', 'Te-pi_0132.jpg', 'Te-pi_0138.jpg', 'Te-pi_0060.jpg', 'Te-pi_0136.jpg', 'Te-pi_0062.jpg', 'Te-pi_0061.jpg', 'Te-pi_0139.jpg', 'Te-pi_0065.jpg', 'Te-pi_0137.jpg', 'Te-pi_0063.jpg', 'Te-pi_0064.jpg', 'Te-pi_0067.jpg', 'Te-pi_0066.jpg', 'Te-pi_0068.jpg', 'Te-pi_0069.jpg', 'Te-pi_0073.jpg', 'Te-pi_0072.jpg', 'Te-pi_0071.jpg', 'Te-pi_0070.jpg', 'Te-pi_0074.jpg', 'Te-pi_0075.jpg', 'Te-pi_0077.jpg', 'Te-pi_0076.jpg', 'Te-pi_0079.jpg', 'Te-pi_0078.jpg', 'Te-pi_0080.jpg', 'Te-pi_0081.jpg', 'Te-pi_0083.jpg', 'Te-pi_0082.jpg', 'Te-pi_0086.jpg', 'Te-pi_0084.jpg', 'Te-pi_0085.jpg', 'Te-pi_0088.jpg', 'Te-pi_0087.jpg', 'Te-pi_0090.jpg', 'Te-pi_0089.jpg', 'Te-pi_0093.jpg', 'Te-pi_0095.jpg', 'Te-pi_0091.jpg', 'Te-pi_0092.jpg', 'Te-pi_0094.jpg', 'Te-pi_0096.jpg', 'Te-pi_0097.jpg', 'Te-pi_0098.jpg', 'Te-pi_0099.jpg', 'Te-pi_0100.jpg', 'Te-pi_0102.jpg', 'Te-pi_0101.jpg', 'Te-pi_0103.jpg', 'Te-pi_0104.jpg', 'Te-pi_0106.jpg', 'Te-pi_0105.jpg', 'Te-pi_0107.jpg', 'Te-pi_0108.jpg', 'Te-pi_0109.jpg', 'Te-pi_0111.jpg', 'Te-pi_0110.jpg']
# Files in subfolder /content/drive/MyDrive/MSC PROJECTS/MSC PROJECT/INPUT/notumor: ['Te-no_0010.jpg', 'Te-no_0011.jpg', 'Te-no_0013.jpg', 'Te-no_0012.jpg', 'Te-no_0014.jpg', 'Te-no_0016.jpg', 'Te-no_0015.jpg', 'Te-no_0017.jpg', 'Te-no_0019.jpg', 'Te-no_0018.jpg', 'Te-no_0020.jpg', 'Te-no_0021.jpg', 'Te-no_0022.jpg', 'Te-no_0023.jpg', 'Te-no_0024.jpg', 'Te-no_0026.jpg', 'Te-no_0025.jpg', 'Te-no_0028.jpg', 'Te-no_0027.jpg', 'Te-no_0029.jpg', 'Te-no_0030.jpg', 'Te-no_0032.jpg', 'Te-no_0034.jpg', 'Te-no_0033.jpg', 'Te-no_0031.jpg', 'Te-no_0036.jpg', 'Te-no_0035.jpg', 'Te-no_0038.jpg', 'Te-no_0037.jpg', 'Te-no_0039.jpg', 'Te-no_0041.jpg', 'Te-no_0043.jpg', 'Te-no_0040.jpg', 'Te-no_0042.jpg', 'Te-no_0045.jpg', 'Te-no_0044.jpg', 'Te-no_0046.jpg', 'Te-no_0047.jpg', 'Te-no_0048.jpg', 'Te-no_0051.jpg', 'Te-no_0050.jpg', 'Te-no_0049.jpg', 'Te-no_0053.jpg', 'Te-no_0052.jpg', 'Te-no_0054.jpg', 'Te-no_0055.jpg', 'Te-no_0056.jpg', 'Te-no_0057.jpg', 'Te-no_0058.jpg', 'Te-no_0060.jpg', 'Te-no_0059.jpg', 'Te-no_0061.jpg', 'Te-no_0063.jpg', 'Te-no_0062.jpg', 'Te-no_0065.jpg', 'Te-no_0064.jpg', 'Te-no_0066.jpg', 'Te-no_0068.jpg', 'Te-no_0067.jpg', 'Te-no_0069.jpg', 'Te-no_0070.jpg', 'Te-no_0071.jpg', 'Te-no_0073.jpg', 'Te-no_0072.jpg', 'Te-no_0075.jpg', 'Te-no_0074.jpg', 'Te-no_0076.jpg', 'Te-no_0078.jpg', 'Te-no_0077.jpg', 'Te-no_0080.jpg', 'Te-no_0079.jpg', 'Te-no_0081.jpg', 'Te-no_0083.jpg', 'Te-no_0139.jpg', 'Te-no_0082.jpg', 'Te-no_0086.jpg', 'Te-no_0140.jpg', 'Te-no_0142.jpg', 'Te-no_0085.jpg', 'Te-no_0143.jpg', 'Te-no_0084.jpg', 'Te-no_0146.jpg', 'Te-no_0088.jpg', 'Te-no_0087.jpg', 'Te-no_0145.jpg', 'Te-no_0144.jpg', 'Te-no_0089.jpg', 'Te-no_0090.jpg', 'Te-no_0149.jpg', 'Te-no_0091.jpg', 'Te-no_0093.jpg', 'Te-no_0148.jpg', 'Te-no_0147.jpg', 'Te-no_0092.jpg', 'Te-no_0150.jpg', 'Te-no_0096.jpg', 'Te-no_0153.jpg', 'Te-no_0151.jpg', 'Te-no_0094.jpg', 'Te-no_0095.jpg', 'Te-no_0154.jpg', 'Te-no_0097.jpg', 'Te-no_0152.jpg', 'Te-no_0098.jpg', 'Te-no_0157.jpg', 'Te-no_0099.jpg', 'Te-no_0101.jpg', 'Te-no_0155.jpg', 'Te-no_0100.jpg', 'Te-no_0156.jpg', 'Te-no_0104.jpg', 'Te-no_0159.jpg', 'Te-no_0160.jpg', 'Te-no_0103.jpg', 'Te-no_0102.jpg', 'Te-no_0105.jpg', 'Te-no_0158.jpg', 'Te-no_0106.jpg', 'Te-no_0161.jpg', 'Te-no_0162.jpg', 'Te-no_0163.jpg', 'Te-no_0108.jpg', 'Te-no_0164.jpg', 'Te-no_0107.jpg', 'Te-no_0109.jpg', 'Te-no_0166.jpg', 'Te-no_0165.jpg', 'Te-no_0110.jpg', 'Te-no_0111.jpg', 'Te-no_0167.jpg', 'Te-no_0168.jpg', 'Te-no_0113.jpg', 'Te-no_0170.jpg', 'Te-no_0171.jpg', 'Te-no_0114.jpg', 'Te-no_0112.jpg', 'Te-no_0116.jpg', 'Te-no_0169.jpg', 'Te-no_0117.jpg', 'Te-no_0172.jpg', 'Te-no_0115.jpg', 'Te-no_0173.jpg', 'Te-no_0118.jpg', 'Te-no_0175.jpg', 'Te-no_0119.jpg', 'Te-no_0120.jpg', 'Te-no_0176.jpg', 'Te-no_0174.jpg', 'Te-no_0122.jpg', 'Te-no_0121.jpg', 'Te-no_0123.jpg', 'Te-no_0178.jpg', 'Te-no_0177.jpg', 'Te-no_0179.jpg', 'Te-no_0124.jpg', 'Te-no_0182.jpg', 'Te-no_0125.jpg', 'Te-no_0181.jpg', 'Te-no_0180.jpg', 'Te-no_0127.jpg', 'Te-no_0184.jpg', 'Te-no_0126.jpg', 'Te-no_0185.jpg', 'Te-no_0183.jpg', 'Te-no_0129.jpg', 'Te-no_0186.jpg', 'Te-no_0128.jpg', 'Te-no_0130.jpg', 'Te-no_0187.jpg', 'Te-no_0188.jpg', 'Te-no_0131.jpg', 'Te-no_0190.jpg', 'Te-no_0132.jpg', 'Te-no_0189.jpg', 'Te-no_0191.jpg', 'Te-no_0193.jpg', 'Te-no_0133.jpg', 'Te-no_0135.jpg', 'Te-no_0134.jpg', 'Te-no_0192.jpg', 'Te-no_0136.jpg', 'Te-no_0194.jpg', 'Te-no_0196.jpg', 'Te-no_0195.jpg', 'Te-no_0138.jpg', 'Te-no_0137.jpg', 'Te-no_0197.jpg', 'Te-no_0141.jpg', 'Te-no_0199.jpg', 'Te-no_0198.jpg', 'Te-no_0200.jpg', 'Te-no_0202.jpg', 'Te-no_0201.jpg', 'Te-no_0204.jpg', 'Te-no_0203.jpg', 'Te-no_0206.jpg', 'Te-no_0205.jpg', 'Te-no_0207.jpg', 'Te-no_0208.jpg', 'Te-no_0210.jpg', 'Te-no_0209.jpg', 'Te-no_0211.jpg']
# Image shapes: [(256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), (256, 256), ( ...

# %%
print("Number of features in training data for SVM:", svm_model.n_features_in_)
print("Number of features in training data for Random Forest:", rf_model.n_features_in_)
print("Number of features in training data for KNN:", knn_model.n_features_in_)
# Out:
# Number of features in training data for SVM: 15876
# Number of features in training data for Random Forest: 15876
# Number of features in training data for KNN: 6804

# %%
import joblib

# Load the models
knn_model = joblib.load('knn_model.pkl')
svm_model = joblib.load('svm_model.pkl')
rf_model = joblib.load('random_forest_model.pkl')

# %%
# Example: Assuming you have the indices of features used for each model
svm_feature_indices = np.arange(15876)
knn_feature_indices = np.arange(6804)
rf_feature_indices = np.arange(15876)  # First 6,804 features (modify according to your actual setup)

# Select feature subsets for each model
X_test_svm = X_test[:, svm_feature_indices]  # Features for SVM and RF
X_test_knn = X_test[:, knn_feature_indices]
X_test_rf = X_test[:, rf_feature_indices]  # Features for KNN

# Now make predictions
y_pred_svm = svm_model.predict(X_test_svm)
y_pred_rf = rf_model.predict(X_test_rf)
y_pred_knn = knn_model.predict(X_test_knn)

# %%
# Combine predictions using majority voting
y_pred_ensemble_num, _ = mode([y_pred_svm_num, y_pred_rf_num, y_pred_knn_num], axis=0)

# Convert numerical predictions back to string labels
y_pred_ensemble = np.array([unique_labels[i] for i in y_pred_ensemble_num.flatten()])

# Evaluate the ensemble
from sklearn.metrics import accuracy_score  # Import accuracy_score
ensemble_accuracy = accuracy_score(y_test, y_pred_ensemble)
print("Ensemble Accuracy:", ensemble_accuracy)
# Out:
# Ensemble Accuracy: 0.2416
